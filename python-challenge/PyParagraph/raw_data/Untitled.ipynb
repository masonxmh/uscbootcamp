# %%
# -*- coding: UTF-8 -*-
"""Resume Analysis Module."""

import os
import string

# Counter is used for the bonus solution
from collections import Counter

# Paths
resume_path = os.path.join("example.txt")

# Skills to match
REQUIRED_SKILLS = {"excel", "python", "mysql", "statistics"}
DESIRED_SKILLS = {"r", "git", "html", "css", "leaflet"}


def load_file(filepath):
    """Helper function to read a file and return the data."""
    with open(filepath, "r") as resume_file_handler:
        return resume_file_handler.read().lower().split()


# Grab the text for a Resume
word_list = load_file(resume_path)

# Create a set of unique words from the resume
resume = set()

# Remove trailing punctuation from words
for token in word_list:
    resume.add(token.split(',')[0].split('.')[0])
print(resume)

# Remove Punctuation that were read as whole words
punctuation = set(string.punctuation)
resume = resume - punctuation
print(resume)

# Calculate the Required Skills Match using Set Intersection
print(resume & REQUIRED_SKILLS)

# Calculate the Desired Skills Match using Set Intersection
print(resume & DESIRED_SKILLS)

# Bonus: Resume Word Count
# ==========================
# Initialize a dictionary with default values equal to zero
word_count = {}.fromkeys(word_list, 0)

# Loop through the word list and count each word.
for word in word_list:
    word_count[word] += 1
print(word_count)

# Bonus using collections.Counter
word_counter = Counter(word_list)
print(word_counter)

# Comparing both word count solutions
print(word_count == word_counter)

# Top 10 Words
print("Top 10 Words")
print("=============")

# Clean Punctuation
_word_count = [word for word in word_count if word not in string.punctuation]

# Clean Stop Words
stop_words = ["and", "with", "using", "##", "working", "in", "to"]
_word_count = [word for word in _word_count if word not in stop_words]

# Sort words by count and print the top 10
sorted_words = []
for word in sorted(_word_count, key=word_count.get, reverse=True)[:10]:
    print(f"Token: {word:20} Count: {word_count[word]}")
# Out:
# {'something', 'of', 'normal', 'great', 'accident', 'his', 'red', 'wayne', 'together', 'with', 'a', 'robes', '鈥淎dam', 'flapping', 'own', 'he', 'in', 'nature', 'crimson', 'an', 'black', 'blot', 'mane', 'was', 'sanity', 'overwhelming', 'like', 'swung', 'upon', 'archangel', 'green', 'face', 'trees', 'raiment', "lion's", 'masquerade', 'him', 'preposterous', 'over', 'wind', 'embraced', 'office', 'saw', 'world', 'how', 'around', 'sword', 'himself', 'this', 'towered', 'stood', 'the', 'exception', 'not', 'back', 'gold', 'conqueror', 'detachment', 'and', 'knew', 'new', 'born', 'frock-coat', 'rationality', 'mockery', 'point', 'wings', 'flung', 'upwards', 'king'}
# {'something', 'of', 'normal', 'great', 'accident', 'his', 'red', 'wayne', 'together', 'with', 'upwards', 'robes', 'flapping', '鈥淎dam', 'own', 'he', 'in', 'nature', 'crimson', 'an', 'black', 'blot', 'mane', 'was', 'sanity', 'overwhelming', 'like', 'swung', 'archangel', 'upon', 'green', 'face', 'trees', 'raiment', "lion's", 'masquerade', 'him', 'preposterous', 'over', 'wind', 'embraced', 'office', 'saw', 'world', 'how', 'around', 'sword', 'himself', 'this', 'towered', 'stood', 'the', 'exception', 'not', 'back', 'gold', 'conqueror', 'detachment', 'and', 'knew', 'new', 'born', 'frock-coat', 'rationality', 'mockery', 'point', 'wings', 'flung', 'a', 'king'}
# set()
# set()
# {'鈥淎dam': 1, 'wayne,': 1, 'the': 12, 'conqueror,': 1, 'with': 3, 'his': 8, 'face': 1, 'flung': 1, 'back': 1, 'and': 10, 'mane': 1, 'like': 2, 'a': 3, "lion's,": 1, 'stood': 1, 'great': 3, 'sword': 1, 'point': 1, 'upwards,': 1, 'red': 3, 'raiment': 1, 'of': 5, 'office': 1, 'flapping': 1, 'around': 1, 'him': 2, 'wings': 1, 'an': 1, 'archangel.': 1, 'king': 1, 'saw,': 1, 'he': 3, 'knew': 1, 'not': 1, 'how,': 1, 'something': 1, 'new': 1, 'overwhelming.': 1, 'green': 1, 'trees': 1, 'robes': 1, 'swung': 1, 'together': 1, 'in': 1, 'wind.': 1, 'preposterous': 1, 'masquerade,': 1, 'born': 1, 'own': 1, 'mockery,': 1, 'towered': 1, 'over': 1, 'embraced': 1, 'world.': 1, 'this': 3, 'was': 4, 'normal,': 1, 'sanity,': 1, 'nature,': 1, 'himself,': 1, 'rationality,': 1, 'detachment': 1, 'black': 2, 'frock-coat,': 1, 'exception': 1, 'accident': 1, 'blot': 1, 'upon': 1, 'world': 1, 'crimson': 1, 'gold."': 1}
# Counter({'the': 12, 'and': 10, 'his': 8, 'of': 5, 'was': 4, 'with': 3, 'a': 3, 'great': 3, 'red': 3, 'he': 3, 'this': 3, 'like': 2, 'him': 2, 'black': 2, '鈥淎dam': 1, 'wayne,': 1, 'conqueror,': 1, 'face': 1, 'flung': 1, 'back': 1, 'mane': 1, "lion's,": 1, 'stood': 1, 'sword': 1, 'point': 1, 'upwards,': 1, 'raiment': 1, 'office': 1, 'flapping': 1, 'around': 1, 'wings': 1, 'an': 1, 'archangel.': 1, 'king': 1, 'saw,': 1, 'knew': 1, 'not': 1, 'how,': 1, 'something': 1, 'new': 1, 'overwhelming.': 1, 'green': 1, 'trees': 1, 'robes': 1, 'swung': 1, 'together': 1, 'in': 1, 'wind.': 1, 'preposterous': 1, 'masquerade,': 1, 'born': 1, 'own': 1, 'mockery,': 1, 'towered': 1, 'over': 1, 'embraced': 1, 'world.': 1, 'normal,': 1, 'sanity,': 1, 'nature,': 1, 'himself,': 1, 'rationality,': 1, 'detachment': 1, 'frock-coat,': 1, 'exception': 1, 'accident': 1, 'blot': 1, 'upon': 1, 'world': 1, 'crimson': 1, 'gold."': 1})
# True
# Top 10 Words
# =============
# Token: the                  Count: 12
# Token: his                  Count: 8
# Token: of                   Count: 5
# Token: was                  Count: 4
# Token: a                    Count: 3
# Token: great                Count: 3
# Token: red                  Count: 3
# Token: he                   Count: 3
# Token: this                 Count: 3
# Token: like                 Count: 2
