# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities_method2.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List & Perform API Call

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

#Generate list
city_list = []
cloud_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
maxtemp_list = []
windspeed_list = []

#initial counter
record_counter=0
set_counter=1
unit = "imperial"
#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_key}&units={unit}&q="


# Identify nearest city for each lat, lng combination
print("Beginning Data Retrieval\n")
print("-"*30)
while len(city_list) <= 500:
# Create a set of random lat and lng combinations
    lats = np.random.uniform(low=-90.000, high=90.000, size=300)
    lngs = np.random.uniform(low=-180.000, high=180.000, size=300)
    lat_lngs = zip(lats, lngs)
    for lat_lng in lat_lngs:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
# If the city is unique, then add it to a our cities list
        if city not in cities:
            cities.append(city)
            response=requests.get(query_url+city).json()
# If the city is in API print name otherwise print not found   

            if "name" in response:
                city_list.append(response["name"])
                cloud_list.append(response["clouds"]["all"])
                country_list.append(response["sys"]["country"])
                date_list.append(response["dt"])
                humidity_list.append(response["main"]["humidity"])
                lat_list.append(response["coord"]["lon"])
                lng_list.append(response["coord"]["lon"])
                maxtemp_list.append(response["main"]["temp_max"])
                windspeed_list.append(response["wind"]["speed"])
                print("Processing Record "+str(record_counter)+" of Set "+str(set_counter)+" | "+ city)
                record_counter+=1
#Add counter
                if record_counter==51:
                    record_counter=1
                    set_counter+=1
                #print("Processing Record "+str(record_counter)+" of Set "+str(set_counter)+" | "+ city)
            else:
                print("City not found. Skipping ...")

print ("-"*30)
print ("\nData Retrieval Complete\n")
print ("-"*30)
print ("Number of cities generated by citipy is "+str(len(cities)))
print ("Number of cities matched with API is "+str(len(city_list)))
# Print the city count to confirm sufficient count
# Out:
# Beginning Data Retrieval
#
# ------------------------------
# Processing Record 0 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 1 | sao filipe
# Processing Record 2 of Set 1 | pangnirtung
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | stokmarknes
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | miyang
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | sorland
# Processing Record 11 of Set 1 | iquique
# Processing Record 12 of Set 1 | maniitsoq
# City not found. Skipping ...
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | lavrentiya
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | christchurch
# City not found. Skipping ...
# Processing Record 18 of Set 1 | vila franca do campo
# Processing Record 19 of Set 1 | vestmannaeyjar
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | kruisfontein
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | baykit
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | yuzhnyy
# Processing Record 28 of Set 1 | hervey bay
# Processing Record 29 of Set 1 | kaitangata
# Processing Record 30 of Set 1 | lufilufi
# Processing Record 31 of Set 1 | moindou
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | manuk mangkaw
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | arraial do cabo
# City not found. Skipping ...
# Processing Record 39 of Set 1 | ayan
# Processing Record 40 of Set 1 | buchanan
# Processing Record 41 of Set 1 | geraldton
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | mandurah
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | cayenne
# Processing Record 47 of Set 1 | nabire
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | minot
# Processing Record 1 of Set 2 | taoudenni
# Processing Record 2 of Set 2 | naze
# Processing Record 3 of Set 2 | kenai
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | touros
# Processing Record 8 of Set 2 | sao jose da coroa grande
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | goderich
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | beringovskiy
# Processing Record 14 of Set 2 | daru
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | zyryanka
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | samarai
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | anadyr
# Processing Record 22 of Set 2 | tornabe
# Processing Record 23 of Set 2 | lorengau
# Processing Record 24 of Set 2 | constitucion
# Processing Record 25 of Set 2 | katsuura
# Processing Record 26 of Set 2 | stonewall
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | narsaq
# Processing Record 29 of Set 2 | saint george
# Processing Record 30 of Set 2 | mansa
# Processing Record 31 of Set 2 | castro alves
# Processing Record 32 of Set 2 | pisco
# Processing Record 33 of Set 2 | tarbes
# Processing Record 34 of Set 2 | fort nelson
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | davidson
# Processing Record 37 of Set 2 | point pleasant
# City not found. Skipping ...
# Processing Record 38 of Set 2 | robertsport
# Processing Record 39 of Set 2 | kurilsk
# Processing Record 40 of Set 2 | bolu
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | kieta
# Processing Record 43 of Set 2 | san patricio
# Processing Record 44 of Set 2 | mount gambier
# City not found. Skipping ...
# Processing Record 45 of Set 2 | sioux lookout
# Processing Record 46 of Set 2 | inuvik
# Processing Record 47 of Set 2 | oktyabrskiy
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | basoko
# Processing Record 50 of Set 2 | aviles
# Processing Record 1 of Set 3 | kasongo-lunda
# Processing Record 2 of Set 3 | mayo
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | berlevag
# Processing Record 5 of Set 3 | rimbey
# Processing Record 6 of Set 3 | elizabeth city
# City not found. Skipping ...
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | arlit
# Processing Record 9 of Set 3 | najran
# Processing Record 10 of Set 3 | namibe
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | busselton
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 | nalut
# City not found. Skipping ...
# Processing Record 15 of Set 3 | bonga
# Processing Record 16 of Set 3 | timon
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | mnogovershinnyy
# Processing Record 20 of Set 3 | eyl
# Processing Record 21 of Set 3 | salamiyah
# Processing Record 22 of Set 3 | saurimo
# Processing Record 23 of Set 3 | kadoma
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | khandyga
# Processing Record 26 of Set 3 | karibib
# Processing Record 27 of Set 3 | aljezur
# Processing Record 28 of Set 3 | keti bandar
# Processing Record 29 of Set 3 | suntar
# Processing Record 30 of Set 3 | konnur
# Processing Record 31 of Set 3 | iralaya
# Processing Record 32 of Set 3 | ilulissat
# Processing Record 33 of Set 3 | itarema
# City not found. Skipping ...
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | kherson
# Processing Record 36 of Set 3 | palauig
# City not found. Skipping ...
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 37 of Set 3 | coquimbo
# Processing Record 38 of Set 3 | yulara
# Processing Record 39 of Set 3 | kilosa
# Processing Record 40 of Set 3 | venado tuerto
# City not found. Skipping ...
# Processing Record 41 of Set 3 | nelson bay
# Processing Record 42 of Set 3 | pitimbu
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | ati
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | broome
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | avarua
# Processing Record 49 of Set 3 | vila velha
# Processing Record 50 of Set 3 | trincomalee
# Processing Record 1 of Set 4 | port hardy
# Processing Record 2 of Set 4 | orapa
# Processing Record 3 of Set 4 | ginir
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | cortez
# Processing Record 6 of Set 4 | mareeba
# Processing Record 7 of Set 4 | miles city
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | felipe carrillo puerto
# Processing Record 11 of Set 4 | brownwood
# Processing Record 12 of Set 4 | vostok
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | perelyub
# Processing Record 15 of Set 4 | villa bruzual
# Processing Record 16 of Set 4 | hohhot
# Processing Record 17 of Set 4 | kovdor
# City not found. Skipping ...
# Processing Record 18 of Set 4 | povenets
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | port lincoln
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 21 of Set 4 | mae hong son
# Processing Record 22 of Set 4 | timmins
# Processing Record 23 of Set 4 | serebryansk
# Processing Record 24 of Set 4 | ahipara
# Processing Record 25 of Set 4 | teguise
# Processing Record 26 of Set 4 | faya
# Processing Record 27 of Set 4 | lima
# Processing Record 28 of Set 4 | raudeberg
# Processing Record 29 of Set 4 | puri
# Processing Record 30 of Set 4 | hambantota
# Processing Record 31 of Set 4 | voiron
# Processing Record 32 of Set 4 | jasper
# Processing Record 33 of Set 4 | batsfjord
# Processing Record 34 of Set 4 | nampula
# Processing Record 35 of Set 4 | santa catalina
# Processing Record 36 of Set 4 | isangel
# Processing Record 37 of Set 4 | kyshtovka
# Processing Record 38 of Set 4 | gaoua
# Processing Record 39 of Set 4 | ostrovnoy
# Processing Record 40 of Set 4 | bagdarin
# Processing Record 41 of Set 4 | opuwo
# Processing Record 42 of Set 4 | mehamn
# Processing Record 43 of Set 4 | sabang
# Processing Record 44 of Set 4 | rio grande
# Processing Record 45 of Set 4 | san cristobal
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | korfovskiy
# Processing Record 48 of Set 4 | aginskoye
# City not found. Skipping ...
# Processing Record 49 of Set 4 | puerto leguizamo
# Processing Record 50 of Set 4 | tateyama
# Processing Record 1 of Set 5 | port alfred
# Processing Record 2 of Set 5 | pandan
# City not found. Skipping ...
# Processing Record 3 of Set 5 | nikolskoye
# Processing Record 4 of Set 5 | saskylakh
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | oussouye
# Processing Record 7 of Set 5 | buriti alegre
# Processing Record 8 of Set 5 | adrar
# City not found. Skipping ...
# Processing Record 9 of Set 5 | vaitape
# Processing Record 10 of Set 5 | nome
# City not found. Skipping ...
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | codrington
# City not found. Skipping ...
# Processing Record 13 of Set 5 | xuddur
# Processing Record 14 of Set 5 | miri
# Processing Record 15 of Set 5 | walvis bay
# Processing Record 16 of Set 5 | porangatu
# City not found. Skipping ...
# Processing Record 17 of Set 5 | silver city
# Processing Record 18 of Set 5 | hay river
# Processing Record 19 of Set 5 | paso de los toros
# Processing Record 20 of Set 5 | sebinkarahisar
# Processing Record 21 of Set 5 | bredasdorp
# Processing Record 22 of Set 5 | dauphin
# Processing Record 23 of Set 5 | clyde river
# Processing Record 24 of Set 5 | san rafael
# Processing Record 25 of Set 5 | alofi
# Processing Record 26 of Set 5 | mbuji-mayi
# Processing Record 27 of Set 5 | isabela
# Processing Record 28 of Set 5 | beaverlodge
# Processing Record 29 of Set 5 | manadhoo
# Processing Record 30 of Set 5 | saryg-sep
# Processing Record 31 of Set 5 | bambous virieux
# City not found. Skipping ...
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | shelburne
# Processing Record 34 of Set 5 | bouna
# Processing Record 35 of Set 5 | nenjiang
# Processing Record 36 of Set 5 | alghero
# City not found. Skipping ...
# Processing Record 37 of Set 5 | wasilla
# Processing Record 38 of Set 5 | erzin
# Processing Record 39 of Set 5 | cubara
# Processing Record 40 of Set 5 | kedrovyy
# Processing Record 41 of Set 5 | palmer
# Processing Record 42 of Set 5 | kysyl-syr
# Processing Record 43 of Set 5 | oystese
# Processing Record 44 of Set 5 | codajas
# Processing Record 45 of Set 5 | comodoro rivadavia
# Processing Record 46 of Set 5 | mana
# Processing Record 47 of Set 5 | bintulu
# City not found. Skipping ...
# Processing Record 48 of Set 5 | nelson
# Processing Record 49 of Set 5 | quimper
# Processing Record 50 of Set 5 | mayumba
# Processing Record 1 of Set 6 | thunder bay
# Processing Record 2 of Set 6 | abu samrah
# Processing Record 3 of Set 6 | henties bay
# Processing Record 4 of Set 6 | hofn
# Processing Record 5 of Set 6 | tabas
# Processing Record 6 of Set 6 | patan
# Processing Record 7 of Set 6 | tiksi
# Processing Record 8 of Set 6 | shakawe
# Processing Record 9 of Set 6 | balabac
# Processing Record 10 of Set 6 | balsas
# Processing Record 11 of Set 6 | portland
# Processing Record 12 of Set 6 | qaanaaq
# Processing Record 13 of Set 6 | ushtobe
# Processing Record 14 of Set 6 | astana
# Processing Record 15 of Set 6 | burgeo
# Processing Record 16 of Set 6 | sindor
# Processing Record 17 of Set 6 | ipoh
# Processing Record 18 of Set 6 | lahij
# Processing Record 19 of Set 6 | moron
# Processing Record 20 of Set 6 | riberalta
# Processing Record 21 of Set 6 | honningsvag
# Processing Record 22 of Set 6 | ygatimi
# Processing Record 23 of Set 6 | luderitz
# Processing Record 24 of Set 6 | saint-pierre
# Processing Record 25 of Set 6 | pilibanga
# Processing Record 26 of Set 6 | vao
# Processing Record 27 of Set 6 | jiexiu
# Processing Record 28 of Set 6 | russell
# Processing Record 29 of Set 6 | pechenga
# Processing Record 30 of Set 6 | grindavik
# Processing Record 31 of Set 6 | tigil
# Processing Record 32 of Set 6 | torbay
# Processing Record 33 of Set 6 | bukachacha
# City not found. Skipping ...
# Processing Record 34 of Set 6 | ancud
# City not found. Skipping ...
# Processing Record 35 of Set 6 | muros
# Processing Record 36 of Set 6 | port moresby
# Processing Record 37 of Set 6 | teresopolis
# Processing Record 38 of Set 6 | marshall
# Processing Record 39 of Set 6 | huandacareo
# Processing Record 40 of Set 6 | wake forest
# Processing Record 41 of Set 6 | srednekolymsk
# Processing Record 42 of Set 6 | bandarbeyla
# Processing Record 43 of Set 6 | garden city
# Processing Record 44 of Set 6 | caravelas
# Processing Record 45 of Set 6 | komsomolskiy
# Processing Record 46 of Set 6 | ponta delgada
# Processing Record 47 of Set 6 | la tuque
# Processing Record 48 of Set 6 | hattiesburg
# Processing Record 49 of Set 6 | kharovsk
# Processing Record 50 of Set 6 | cap malheureux
# Processing Record 1 of Set 7 | banff
# Processing Record 2 of Set 7 | sitka
# Processing Record 3 of Set 7 | coruripe
# Processing Record 4 of Set 7 | beloha
# Processing Record 5 of Set 7 | muisne
# Processing Record 6 of Set 7 | bar harbor
# Processing Record 7 of Set 7 | pacific grove
# Processing Record 8 of Set 7 | kahului
# Processing Record 9 of Set 7 | ruy barbosa
# Processing Record 10 of Set 7 | gornopravdinsk
# Processing Record 11 of Set 7 | terney
# Processing Record 12 of Set 7 | necochea
# Processing Record 13 of Set 7 | sibolga
# Processing Record 14 of Set 7 | orange cove
# Processing Record 15 of Set 7 | cabo san lucas
# Processing Record 16 of Set 7 | gosainganj
# Processing Record 17 of Set 7 | san quintin
# Processing Record 18 of Set 7 | lagoa
# Processing Record 19 of Set 7 | madingou
# Processing Record 20 of Set 7 | san jose de guanipa
# Processing Record 21 of Set 7 | vardo
# Processing Record 22 of Set 7 | shellbrook
# Processing Record 23 of Set 7 | whitehorse
# Processing Record 24 of Set 7 | poum
# Processing Record 25 of Set 7 | windhoek
# Processing Record 26 of Set 7 | pailon
# Processing Record 27 of Set 7 | betulia
# Processing Record 28 of Set 7 | sobolevo
# Processing Record 29 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 7 | vytegra
# Processing Record 31 of Set 7 | roma
# Processing Record 32 of Set 7 | humaita
# Processing Record 33 of Set 7 | esperance
# Processing Record 34 of Set 7 | astoria
# Processing Record 35 of Set 7 | ales
# Processing Record 36 of Set 7 | tumut
# Processing Record 37 of Set 7 | darhan
# Processing Record 38 of Set 7 | shingu
# Processing Record 39 of Set 7 | giporlos
# Processing Record 40 of Set 7 | saint-leu
# Processing Record 41 of Set 7 | lakes entrance
# Processing Record 42 of Set 7 | kudahuvadhoo
# Processing Record 43 of Set 7 | shaoyang
# Processing Record 44 of Set 7 | iwanai
# Processing Record 45 of Set 7 | topolobampo
# Processing Record 46 of Set 7 | sarangani
# Processing Record 47 of Set 7 | zhigansk
# City not found. Skipping ...
# Processing Record 48 of Set 7 | grand-lahou
# Processing Record 49 of Set 7 | auki
# Processing Record 50 of Set 7 | alta floresta
# Processing Record 1 of Set 8 | upernavik
# Processing Record 2 of Set 8 | luziania
# Processing Record 3 of Set 8 | saldanha
# Processing Record 4 of Set 8 | dunedin
# Processing Record 5 of Set 8 | durham
# Processing Record 6 of Set 8 | jumla
# Processing Record 7 of Set 8 | liusha
# Processing Record 8 of Set 8 | boden
# Processing Record 9 of Set 8 | ballina
# City not found. Skipping ...
# Processing Record 10 of Set 8 | muroto
# Processing Record 11 of Set 8 | lasa
# Processing Record 12 of Set 8 | kichera
# Processing Record 13 of Set 8 | bubaque
# City not found. Skipping ...
# Processing Record 14 of Set 8 | cascais
# City not found. Skipping ...
# Processing Record 15 of Set 8 | lata
# Processing Record 16 of Set 8 | flinders
# Processing Record 17 of Set 8 | inhambane
# City not found. Skipping ...
# Processing Record 18 of Set 8 | kutum
# Processing Record 19 of Set 8 | ojinaga
# Processing Record 20 of Set 8 | general roca
# Processing Record 21 of Set 8 | jadu
# Processing Record 22 of Set 8 | santa luzia
# Processing Record 23 of Set 8 | gizo
# City not found. Skipping ...
# Processing Record 24 of Set 8 | santa marta
# Processing Record 25 of Set 8 | manjeshwar
# Processing Record 26 of Set 8 | jalu
# Processing Record 27 of Set 8 | lampang
# Processing Record 28 of Set 8 | bol
# Processing Record 29 of Set 8 | turayf
# Processing Record 30 of Set 8 | kreminna
# Processing Record 31 of Set 8 | tarancon
# City not found. Skipping ...
# Processing Record 32 of Set 8 | linxia
# Processing Record 33 of Set 8 | port-gentil
# Processing Record 34 of Set 8 | valparaiso
# Processing Record 35 of Set 8 | paralimni
# Processing Record 36 of Set 8 | tuy hoa
# City not found. Skipping ...
# Processing Record 37 of Set 8 | gat
# Processing Record 38 of Set 8 | santa
# Processing Record 39 of Set 8 | north bay
# Processing Record 40 of Set 8 | xingyi
# City not found. Skipping ...
# Processing Record 41 of Set 8 | malanje
# Processing Record 42 of Set 8 | groningen
# Processing Record 43 of Set 8 | riyadh
# Processing Record 44 of Set 8 | camargo
# Processing Record 45 of Set 8 | mantua
# Processing Record 46 of Set 8 | cassilandia
# Processing Record 47 of Set 8 | roald
# Processing Record 48 of Set 8 | bathsheba
# City not found. Skipping ...
# Processing Record 49 of Set 8 | utica
# Processing Record 50 of Set 8 | alzamay
# City not found. Skipping ...
# Processing Record 1 of Set 9 | los llanos de aridane
# Processing Record 2 of Set 9 | negombo
# Processing Record 3 of Set 9 | morondava
# Processing Record 4 of Set 9 | richards bay
# Processing Record 5 of Set 9 | santa rosa
# Processing Record 6 of Set 9 | aksarka
# Processing Record 7 of Set 9 | hamilton
# Processing Record 8 of Set 9 | illela
# Processing Record 9 of Set 9 | fairbanks
# Processing Record 10 of Set 9 | tual
# Processing Record 11 of Set 9 | hareid
# Processing Record 12 of Set 9 | luena
# Processing Record 13 of Set 9 | bakchar
# Processing Record 14 of Set 9 | high level
# City not found. Skipping ...
# Processing Record 15 of Set 9 | batagay
# Processing Record 16 of Set 9 | harper
# Processing Record 17 of Set 9 | hovd
# Processing Record 18 of Set 9 | veraval
# Processing Record 19 of Set 9 | balkanabat
# Processing Record 20 of Set 9 | oranjestad
# Processing Record 21 of Set 9 | saint-paul
# Processing Record 22 of Set 9 | nurlat
# City not found. Skipping ...
# Processing Record 23 of Set 9 | rocha
# Processing Record 24 of Set 9 | manicore
# Processing Record 25 of Set 9 | baiao
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | swift current
# Processing Record 28 of Set 9 | chuzhou
# Processing Record 29 of Set 9 | puerto escondido
# Processing Record 30 of Set 9 | rio gallegos
# Processing Record 31 of Set 9 | shimoda
# Processing Record 32 of Set 9 | teya
# Processing Record 33 of Set 9 | viedma
# Processing Record 34 of Set 9 | kosh-agach
# Processing Record 35 of Set 9 | yerbogachen
# Processing Record 36 of Set 9 | salinopolis
# Processing Record 37 of Set 9 | chapais
# City not found. Skipping ...
# Processing Record 38 of Set 9 | waingapu
# Processing Record 39 of Set 9 | port blair
# City not found. Skipping ...
# Processing Record 40 of Set 9 | almaznyy
# Processing Record 41 of Set 9 | verkhoyansk
# Processing Record 42 of Set 9 | broken hill
# Processing Record 43 of Set 9 | vieques
# Processing Record 44 of Set 9 | buraydah
# Processing Record 45 of Set 9 | buta
# Processing Record 46 of Set 9 | husavik
# Processing Record 47 of Set 9 | brae
# Processing Record 48 of Set 9 | kalakamati
# Processing Record 49 of Set 9 | alindao
# Processing Record 50 of Set 9 | gijon
# Processing Record 1 of Set 10 | buluang
# Processing Record 2 of Set 10 | brigantine
# Processing Record 3 of Set 10 | batagay-alyta
# Processing Record 4 of Set 10 | concepcion
# Processing Record 5 of Set 10 | orbetello
# Processing Record 6 of Set 10 | kastamonu
# Processing Record 7 of Set 10 | souillac
# Processing Record 8 of Set 10 | byron bay
# Processing Record 9 of Set 10 | bayir
# Processing Record 10 of Set 10 | inirida
# Processing Record 11 of Set 10 | meulaboh
# Processing Record 12 of Set 10 | zabid
# Processing Record 13 of Set 10 | kita
# Processing Record 14 of Set 10 | maryborough
# Processing Record 15 of Set 10 | mahibadhoo
# Processing Record 16 of Set 10 | ilhabela
# Processing Record 17 of Set 10 | banyo
# Processing Record 18 of Set 10 | minab
# Processing Record 19 of Set 10 | sheridan
# City not found. Skipping ...
# Processing Record 20 of Set 10 | amga
# Processing Record 21 of Set 10 | jilib
# Processing Record 22 of Set 10 | kargopol
# Processing Record 23 of Set 10 | tucupita
# Processing Record 24 of Set 10 | grand gaube
# Processing Record 25 of Set 10 | mount isa
# Processing Record 26 of Set 10 | marzuq
# Processing Record 27 of Set 10 | victoria
# Processing Record 28 of Set 10 | kabanjahe
# Processing Record 29 of Set 10 | lujiang
# City not found. Skipping ...
# Processing Record 30 of Set 10 | ekhabi
# Processing Record 31 of Set 10 | menongue
# Processing Record 32 of Set 10 | mindelo
# Processing Record 33 of Set 10 | morehead
# Processing Record 34 of Set 10 | cloquet
# Processing Record 35 of Set 10 | sanandaj
# Processing Record 36 of Set 10 | benavente
# City not found. Skipping ...
# Processing Record 37 of Set 10 | koshurnikovo
# Processing Record 38 of Set 10 | mahon
# Processing Record 39 of Set 10 | doctor arroyo
# Processing Record 40 of Set 10 | lianzhou
# Processing Record 41 of Set 10 | acapulco
# Processing Record 42 of Set 10 | anderson
# Processing Record 43 of Set 10 | panguna
# Processing Record 44 of Set 10 | concarneau
# Processing Record 45 of Set 10 | la libertad
# Processing Record 46 of Set 10 | porto velho
# Processing Record 47 of Set 10 | les cayes
# Processing Record 48 of Set 10 | martapura
# Processing Record 49 of Set 10 | teahupoo
# Processing Record 50 of Set 10 | evensk
# Processing Record 1 of Set 11 | aksu
# City not found. Skipping ...
# Processing Record 2 of Set 11 | mouzouras
# Processing Record 3 of Set 11 | semiletka
# Processing Record 4 of Set 11 | fortuna
# Processing Record 5 of Set 11 | gweru
# Processing Record 6 of Set 11 | porto novo
# Processing Record 7 of Set 11 | barcelos
# Processing Record 8 of Set 11 | fowa
# Processing Record 9 of Set 11 | sur
# Processing Record 10 of Set 11 | seoul
# Processing Record 11 of Set 11 | choix
# Processing Record 12 of Set 11 | caraballeda
# Processing Record 13 of Set 11 | tucuman
# City not found. Skipping ...
# Processing Record 14 of Set 11 | half moon bay
# Processing Record 15 of Set 11 | basco
# Processing Record 16 of Set 11 | torquay
# Processing Record 17 of Set 11 | abnub
# Processing Record 18 of Set 11 | ust-omchug
# Processing Record 19 of Set 11 | jiazi
# Processing Record 20 of Set 11 | yeppoon
# Processing Record 21 of Set 11 | kiama
# Processing Record 22 of Set 11 | igarka
# City not found. Skipping ...
# Processing Record 23 of Set 11 | san-pedro
# Processing Record 24 of Set 11 | kokoda
# Processing Record 25 of Set 11 | marsh harbour
# Processing Record 26 of Set 11 | murray bridge
# Processing Record 27 of Set 11 | klaksvik
# Processing Record 28 of Set 11 | kloulklubed
# Processing Record 29 of Set 11 | exeter
# Processing Record 30 of Set 11 | mumford
# Processing Record 31 of Set 11 | soledade
# Processing Record 32 of Set 11 | impfondo
# Processing Record 33 of Set 11 | ipixuna
# Processing Record 34 of Set 11 | wairoa
# Processing Record 35 of Set 11 | vetlanda
# Processing Record 36 of Set 11 | bulgan
# Processing Record 37 of Set 11 | kiunga
# Processing Record 38 of Set 11 | yabelo
# Processing Record 39 of Set 11 | dawlatabad
# Processing Record 40 of Set 11 | wegrow
# Processing Record 41 of Set 11 | mangan
# Processing Record 42 of Set 11 | sao joao da barra
# Processing Record 43 of Set 11 | hualmay
# Processing Record 44 of Set 11 | praia da vitoria
# Processing Record 45 of Set 11 | matara
# Processing Record 46 of Set 11 | sept-iles
# Processing Record 47 of Set 11 | akdepe
# Processing Record 48 of Set 11 | indianola
# Processing Record 49 of Set 11 | erenhot
# Processing Record 50 of Set 11 | cockburn town
# City not found. Skipping ...
# Processing Record 1 of Set 12 | siquinala
# Processing Record 2 of Set 12 | parana
# City not found. Skipping ...
# ------------------------------
#
# Data Retrieval Complete
#
# ------------------------------
# Number of cities generated by citipy is 606
# Number of cities matched with API is 553

# %%
#try: check.append(response['weather'][0]['description'])
        #except:print("City not found. Skipping ...")
#cities

# %%
# # List for holding lat_lngs and cities
# lat_lngs = []
# cities = []

# # Create a set of random lat and lng combinations
# lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
# lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
# lat_lngs = zip(lats, lngs)

# # Identify nearest city for each lat, lng combination
# for lat_lng in lat_lngs:
#     city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
#     # If the city is unique, then add it to a our cities list
#     if city not in cities:
#         cities.append(city)

# # Print the city count to confirm sufficient count
# len(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# #Save config information
# url = "http://api.openweathermap.org/data/2.5/weather?"
# query_url = f"{url}appid={api_key}&q="

# #Generate list initial counter
# city_list = []
# cloud_list = []
# country_list = []
# date_list = []
# humidity_list = []
# lat_list = []
# lng_list = []
# maxtemp_list = []
# windspeed_list = []
# #initial counter
# record_counter=0
# set_counter=1

# print("Beginning Data Retrieval"+"\n"+"-"*30)

# for cityname in cities:
#     response=requests.get(query_url+cityname).json()
#     #try: check.append(response['weather'][0]['description'])
#     #except:print("City not found. Skipping ...")
#     if "name" in response:
#         city_list.append(response["name"])
#         cloud_list.append(response["clouds"]["all"])
#         country_list.append(response["sys"]["country"])
#         date_list.append(response["dt"])
#         humidity_list.append(response["main"]["humidity"])
#         lat_list.append(response["coord"]["lon"])
#         lng_list.append(response["coord"]["lon"])
#         maxtemp_list.append(response["main"]["temp_max"])
#         windspeed_list.append(response["wind"]["speed"])
        
#         record_counter+=1
#         if record_counter==51:
#             record_counter=1
#             set_counter+=1
#         print("Processing Record "+str(record_counter)+" of Set "+str(set_counter)+" | "+ cityname)
#     else:
#         print("City not found. Skipping ...")

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Generate weather data frame
weather_df = pd.DataFrame({"City": city_list,
                           "Cloudiness" : cloud_list,
                           "Country": country_list,
                           "Date": date_list,
                           "Humidity" : humidity_list,
                           "Lat": lat_list,
                           "Lng":lng_list,
                            "Max Temp": maxtemp_list,
                            "Wind Speed": windspeed_list
                           })

weather_df.count()
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Lat           553
# Lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %%
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity     Lat     Lng  \
# 0  Tuktoyaktuk          75      CA  1571536227        85 -133.03 -133.03
# 1   Sao Filipe          79      CV  1571536227        85  -24.50  -24.50
# 2  Pangnirtung          89      CA  1571536052        54  -65.72  -65.72
# 3        Vaini          75      IN  1571535942       100   74.49   74.49
# 4  Stokmarknes          97      NO  1571536228        78   14.91   14.91
#
#    Max Temp  Wind Speed
# 0     23.00       12.75
# 1     78.56       18.54
# 2     13.90        2.04
# 3     68.00        3.62
# 4     32.00        7.00

# %%
#save data frame to csv
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature(10/19/2019)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude vs. Temperature Plot_method2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(10/19/2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude vs. Humidity Plot_method2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness(10/19/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Cloudiness Plot_method2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed(10/19/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Wind Speed_method2.png")

# Show plot
plt.show()

# %% [markdown]
# ### Analysis
# * The temperature of cities near equator are typically warmer
# * The cities in northern hemisphere has a relative higher humidity than southern hemisphere
# * The cities in northern hemisphere has a relative higher cloudiness than southern hemisphere
# * Most cities wind speed range is between 0-15mph
