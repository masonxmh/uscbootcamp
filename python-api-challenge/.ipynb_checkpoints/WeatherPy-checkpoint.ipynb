# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
unit="imperial"
query_url = f"{url}appid={api_key}&units={unit}&q="

#Generate list initial counter
city_list = []
cloud_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
maxtemp_list = []
windspeed_list = []
#initial counter
record_counter=0
set_counter=1

print("Beginning Data Retrieval"+"\n"+"-"*30)

for cityname in cities:
    
    #try: check.append(response['weather'][0]['description'])
    #except:print("City not found. Skipping ...")
    try:
        response=requests.get(query_url+cityname).json()
        city_list.append(response["name"])
        cloud_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        maxtemp_list.append(response["main"]["temp_max"])
        windspeed_list.append(response["wind"]["speed"])
        
        record_counter+=1
        if record_counter==51:
            record_counter=1
            set_counter+=1
        print("Processing Record "+str(record_counter)+" of Set "+str(set_counter)+" | "+ cityname)
    except:
        print("City not found. Skipping ...")
print ("-"*30)
print ("\nData Retrieval Complete\n")
print ("-"*30)
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | ucluelet
# Processing Record 6 of Set 1 | koungheul
# Processing Record 7 of Set 1 | lamar
# Processing Record 8 of Set 1 | ferrol
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | aksay
# Processing Record 14 of Set 1 | hualmay
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | kaitangata
# Processing Record 17 of Set 1 | lugo
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | tigil
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | lavrentiya
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 24 of Set 1 | brae
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | dingle
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | puerto ayora
# City not found. Skipping ...
# Processing Record 31 of Set 1 | kosa
# Processing Record 32 of Set 1 | sao gabriel da cachoeira
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | atuona
# City not found. Skipping ...
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | sao filipe
# Processing Record 37 of Set 1 | sibolga
# Processing Record 38 of Set 1 | shenjiamen
# Processing Record 39 of Set 1 | skalat
# Processing Record 40 of Set 1 | panama city
# Processing Record 41 of Set 1 | vaitape
# Processing Record 42 of Set 1 | esperance
# Processing Record 43 of Set 1 | vestmannaeyjar
# Processing Record 44 of Set 1 | mutis
# Processing Record 45 of Set 1 | kodiak
# City not found. Skipping ...
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | ikom
# City not found. Skipping ...
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | giyani
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | te anau
# Processing Record 3 of Set 2 | barrow
# City not found. Skipping ...
# Processing Record 4 of Set 2 | el tigre
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | sestri levante
# Processing Record 7 of Set 2 | aklavik
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | hokitika
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | bereda
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | novikovo
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | polunochnoye
# City not found. Skipping ...
# Processing Record 18 of Set 2 | camden
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | chifeng
# Processing Record 21 of Set 2 | fairbanks
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | edson
# Processing Record 24 of Set 2 | cururupu
# Processing Record 25 of Set 2 | babu
# City not found. Skipping ...
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | wagar
# Processing Record 28 of Set 2 | wasilla
# Processing Record 29 of Set 2 | rocha
# Processing Record 30 of Set 2 | kudahuvadhoo
# Processing Record 31 of Set 2 | omboue
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | dukat
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | cartagena
# Processing Record 36 of Set 2 | altenburg
# Processing Record 37 of Set 2 | zalesovo
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | saldanha
# Processing Record 40 of Set 2 | kahului
# Processing Record 41 of Set 2 | longyearbyen
# Processing Record 42 of Set 2 | khorixas
# Processing Record 43 of Set 2 | jizan
# Processing Record 44 of Set 2 | ostrovnoy
# Processing Record 45 of Set 2 | tazmalt
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | mersing
# Processing Record 48 of Set 2 | bahia de caraquez
# Processing Record 49 of Set 2 | aksu
# Processing Record 50 of Set 2 | sancraieni
# City not found. Skipping ...
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 1 of Set 3 | anajatuba
# Processing Record 2 of Set 3 | gatton
# Processing Record 3 of Set 3 | paamiut
# Processing Record 4 of Set 3 | altamira
# Processing Record 5 of Set 3 | san anselmo
# Processing Record 6 of Set 3 | fort nelson
# Processing Record 7 of Set 3 | hamilton
# Processing Record 8 of Set 3 | chuy
# City not found. Skipping ...
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | phalaborwa
# Processing Record 11 of Set 3 | carauari
# Processing Record 12 of Set 3 | ahipara
# City not found. Skipping ...
# Processing Record 13 of Set 3 | hilo
# Processing Record 14 of Set 3 | ballina
# Processing Record 15 of Set 3 | peterhead
# Processing Record 16 of Set 3 | dudinka
# Processing Record 17 of Set 3 | mount gambier
# Processing Record 18 of Set 3 | lorengau
# Processing Record 19 of Set 3 | kinango
# Processing Record 20 of Set 3 | pacific grove
# Processing Record 21 of Set 3 | ilulissat
# Processing Record 22 of Set 3 | semporna
# Processing Record 23 of Set 3 | nikolskoye
# Processing Record 24 of Set 3 | roma
# Processing Record 25 of Set 3 | komsomolskiy
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | avera
# Processing Record 28 of Set 3 | kartaly
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | geraldton
# Processing Record 31 of Set 3 | kallifitos
# Processing Record 32 of Set 3 | tsaratanana
# Processing Record 33 of Set 3 | nome
# Processing Record 34 of Set 3 | auki
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | tres coracoes
# Processing Record 37 of Set 3 | sitka
# Processing Record 38 of Set 3 | port macquarie
# Processing Record 39 of Set 3 | acapulco
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | scarborough
# Processing Record 42 of Set 3 | barcelos
# Processing Record 43 of Set 3 | talaya
# Processing Record 44 of Set 3 | dubbo
# Processing Record 45 of Set 3 | yulara
# Processing Record 46 of Set 3 | rutland
# Processing Record 47 of Set 3 | kapaa
# Processing Record 48 of Set 3 | benguela
# Processing Record 49 of Set 3 | makakilo city
# Processing Record 50 of Set 3 | impfondo
# Processing Record 1 of Set 4 | wuwei
# Processing Record 2 of Set 4 | norman wells
# Processing Record 3 of Set 4 | mufumbwe
# Processing Record 4 of Set 4 | los llanos de aridane
# Processing Record 5 of Set 4 | sistranda
# Processing Record 6 of Set 4 | kulu
# Processing Record 7 of Set 4 | severo-kurilsk
# Processing Record 8 of Set 4 | juye
# Processing Record 9 of Set 4 | adeje
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 10 of Set 4 | lakselv
# City not found. Skipping ...
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | saint anthony
# Processing Record 13 of Set 4 | jacareacanga
# Processing Record 14 of Set 4 | saint-augustin
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | atasu
# Processing Record 17 of Set 4 | marawi
# City not found. Skipping ...
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | fortuna
# Processing Record 20 of Set 4 | chumphon
# Processing Record 21 of Set 4 | pevek
# Processing Record 22 of Set 4 | college
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | mangrol
# Processing Record 25 of Set 4 | sapa
# Processing Record 26 of Set 4 | quatre cocos
# Processing Record 27 of Set 4 | razole
# Processing Record 28 of Set 4 | pangnirtung
# Processing Record 29 of Set 4 | lowestoft
# Processing Record 30 of Set 4 | lagoa
# Processing Record 31 of Set 4 | shevchenkove
# Processing Record 32 of Set 4 | yumen
# City not found. Skipping ...
# Processing Record 33 of Set 4 | bindura
# Processing Record 34 of Set 4 | izmalkovo
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | sisimiut
# Processing Record 37 of Set 4 | marsa matruh
# Processing Record 38 of Set 4 | shirakawa
# Processing Record 39 of Set 4 | mahebourg
# Processing Record 40 of Set 4 | haines junction
# Processing Record 41 of Set 4 | xining
# Processing Record 42 of Set 4 | puerto del rosario
# Processing Record 43 of Set 4 | bandipur
# Processing Record 44 of Set 4 | clyde river
# Processing Record 45 of Set 4 | tuktoyaktuk
# Processing Record 46 of Set 4 | phetchabun
# Processing Record 47 of Set 4 | devils lake
# Processing Record 48 of Set 4 | challans
# Processing Record 49 of Set 4 | castrillon
# City not found. Skipping ...
# Processing Record 50 of Set 4 | kushiro
# Processing Record 1 of Set 5 | pisco
# Processing Record 2 of Set 5 | husavik
# Processing Record 3 of Set 5 | touros
# Processing Record 4 of Set 5 | jumla
# Processing Record 5 of Set 5 | piuma
# Processing Record 6 of Set 5 | kungurtug
# Processing Record 7 of Set 5 | airai
# Processing Record 8 of Set 5 | ous
# Processing Record 9 of Set 5 | benjamin hill
# Processing Record 10 of Set 5 | presidencia roque saenz pena
# Processing Record 11 of Set 5 | palembang
# Processing Record 12 of Set 5 | dikson
# City not found. Skipping ...
# Processing Record 13 of Set 5 | karratha
# Processing Record 14 of Set 5 | rio grande
# Processing Record 15 of Set 5 | plettenberg bay
# Processing Record 16 of Set 5 | meulaboh
# Processing Record 17 of Set 5 | yar-sale
# Processing Record 18 of Set 5 | dire dawa
# Processing Record 19 of Set 5 | vila velha
# Processing Record 20 of Set 5 | hagen
# Processing Record 21 of Set 5 | manzil salim
# Processing Record 22 of Set 5 | san patricio
# Processing Record 23 of Set 5 | coleraine
# Processing Record 24 of Set 5 | khor
# City not found. Skipping ...
# Processing Record 25 of Set 5 | mareeba
# Processing Record 26 of Set 5 | harper
# Processing Record 27 of Set 5 | boffa
# Processing Record 28 of Set 5 | dasoguz
# Processing Record 29 of Set 5 | lazarev
# Processing Record 30 of Set 5 | aden
# Processing Record 31 of Set 5 | chokurdakh
# Processing Record 32 of Set 5 | vostok
# Processing Record 33 of Set 5 | alofi
# Processing Record 34 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 5 | isangel
# Processing Record 36 of Set 5 | la palma
# Processing Record 37 of Set 5 | icod de los vinos
# Processing Record 38 of Set 5 | savannah bight
# Processing Record 39 of Set 5 | caravelas
# Processing Record 40 of Set 5 | padang
# Processing Record 41 of Set 5 | khankala
# Processing Record 42 of Set 5 | bambous virieux
# Processing Record 43 of Set 5 | road town
# Processing Record 44 of Set 5 | huarmey
# Processing Record 45 of Set 5 | hit
# Processing Record 46 of Set 5 | tomatlan
# City not found. Skipping ...
# Processing Record 47 of Set 5 | narasannapeta
# Processing Record 48 of Set 5 | olinda
# Processing Record 49 of Set 5 | abu samrah
# Processing Record 50 of Set 5 | vvedenskoye
# Processing Record 1 of Set 6 | kavieng
# City not found. Skipping ...
# Processing Record 2 of Set 6 | skibbereen
# Processing Record 3 of Set 6 | chimoio
# City not found. Skipping ...
# Processing Record 4 of Set 6 | teya
# Processing Record 5 of Set 6 | tarakan
# Processing Record 6 of Set 6 | marsh harbour
# Processing Record 7 of Set 6 | vangaindrano
# Processing Record 8 of Set 6 | minsk
# Processing Record 9 of Set 6 | mandalgovi
# City not found. Skipping ...
# Processing Record 10 of Set 6 | castro
# Processing Record 11 of Set 6 | lasa
# Processing Record 12 of Set 6 | viedma
# Processing Record 13 of Set 6 | golden
# Processing Record 14 of Set 6 | sur
# Processing Record 15 of Set 6 | moroni
# Processing Record 16 of Set 6 | marystown
# Processing Record 17 of Set 6 | saintes
# Processing Record 18 of Set 6 | gao
# Processing Record 19 of Set 6 | provideniya
# Processing Record 20 of Set 6 | shabo
# Processing Record 21 of Set 6 | nador
# Processing Record 22 of Set 6 | saint george
# City not found. Skipping ...
# Processing Record 23 of Set 6 | cabo san lucas
# Processing Record 24 of Set 6 | abu dhabi
# Processing Record 25 of Set 6 | san juan de la maguana
# Processing Record 26 of Set 6 | praia da vitoria
# Processing Record 27 of Set 6 | trat
# Processing Record 28 of Set 6 | luncavita
# Processing Record 29 of Set 6 | biak
# Processing Record 30 of Set 6 | mizdah
# Processing Record 31 of Set 6 | odienne
# Processing Record 32 of Set 6 | melbu
# Processing Record 33 of Set 6 | dunedin
# Processing Record 34 of Set 6 | fort saint james
# Processing Record 35 of Set 6 | tashtyp
# Processing Record 36 of Set 6 | walvis bay
# Processing Record 37 of Set 6 | lata
# Processing Record 38 of Set 6 | grand gaube
# Processing Record 39 of Set 6 | san policarpo
# Processing Record 40 of Set 6 | curup
# Processing Record 41 of Set 6 | portland
# Processing Record 42 of Set 6 | alice springs
# Processing Record 43 of Set 6 | pakxe
# City not found. Skipping ...
# Processing Record 44 of Set 6 | north platte
# Processing Record 45 of Set 6 | san jeronimo
# Processing Record 46 of Set 6 | alta floresta
# Processing Record 47 of Set 6 | bontang
# Processing Record 48 of Set 6 | nhamunda
# Processing Record 49 of Set 6 | deputatskiy
# Processing Record 50 of Set 6 | tabas
# Processing Record 1 of Set 7 | gopalpur
# Processing Record 2 of Set 7 | barcelona
# Processing Record 3 of Set 7 | naze
# Processing Record 4 of Set 7 | palmer
# City not found. Skipping ...
# Processing Record 5 of Set 7 | henties bay
# Processing Record 6 of Set 7 | visnes
# Processing Record 7 of Set 7 | dabat
# Processing Record 8 of Set 7 | juba
# Processing Record 9 of Set 7 | drumnadrochit
# Processing Record 10 of Set 7 | nizhnevartovsk
# Processing Record 11 of Set 7 | norsup
# Processing Record 12 of Set 7 | buala
# Processing Record 13 of Set 7 | jalu
# Processing Record 14 of Set 7 | pimentel
# Processing Record 15 of Set 7 | lompoc
# Processing Record 16 of Set 7 | moyale
# Processing Record 17 of Set 7 | mangai
# Processing Record 18 of Set 7 | ginda
# Processing Record 19 of Set 7 | hofn
# Processing Record 20 of Set 7 | cervo
# Processing Record 21 of Set 7 | okha
# Processing Record 22 of Set 7 | murindo
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | camacupa
# Processing Record 25 of Set 7 | westport
# Processing Record 26 of Set 7 | kruisfontein
# Processing Record 27 of Set 7 | srednekolymsk
# Processing Record 28 of Set 7 | ambilobe
# Processing Record 29 of Set 7 | samarai
# Processing Record 30 of Set 7 | cheyenne
# Processing Record 31 of Set 7 | birobidzhan
# Processing Record 32 of Set 7 | chapais
# Processing Record 33 of Set 7 | churapcha
# City not found. Skipping ...
# Processing Record 34 of Set 7 | pakxan
# Processing Record 35 of Set 7 | huanuni
# Processing Record 36 of Set 7 | ancud
# Processing Record 37 of Set 7 | camargo
# Processing Record 38 of Set 7 | beringovskiy
# Processing Record 39 of Set 7 | shimoda
# City not found. Skipping ...
# Processing Record 40 of Set 7 | vanimo
# Processing Record 41 of Set 7 | suntar
# Processing Record 42 of Set 7 | cayenne
# City not found. Skipping ...
# Processing Record 43 of Set 7 | batagay-alyta
# Processing Record 44 of Set 7 | athabasca
# Processing Record 45 of Set 7 | nicoya
# Processing Record 46 of Set 7 | nadvoitsy
# Processing Record 47 of Set 7 | narsaq
# Processing Record 48 of Set 7 | morehead
# Processing Record 49 of Set 7 | antofagasta
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 50 of Set 7 | belaya gora
# Processing Record 1 of Set 8 | goure
# Processing Record 2 of Set 8 | calbuco
# Processing Record 3 of Set 8 | parakai
# Processing Record 4 of Set 8 | arraial do cabo
# City not found. Skipping ...
# Processing Record 5 of Set 8 | amapa
# Processing Record 6 of Set 8 | punta alta
# Processing Record 7 of Set 8 | tuatapere
# Processing Record 8 of Set 8 | port lincoln
# Processing Record 9 of Set 8 | sao joao da barra
# Processing Record 10 of Set 8 | ust-maya
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 11 of Set 8 | the valley
# Processing Record 12 of Set 8 | namibe
# Processing Record 13 of Set 8 | raudeberg
# Processing Record 14 of Set 8 | shache
# Processing Record 15 of Set 8 | hovd
# Processing Record 16 of Set 8 | aripuana
# Processing Record 17 of Set 8 | matagami
# Processing Record 18 of Set 8 | goderich
# City not found. Skipping ...
# Processing Record 19 of Set 8 | jati
# Processing Record 20 of Set 8 | dalbandin
# City not found. Skipping ...
# Processing Record 21 of Set 8 | kitaibaraki
# Processing Record 22 of Set 8 | vidim
# Processing Record 23 of Set 8 | oyem
# Processing Record 24 of Set 8 | mondovi
# Processing Record 25 of Set 8 | pontianak
# Processing Record 26 of Set 8 | shu
# Processing Record 27 of Set 8 | loknya
# Processing Record 28 of Set 8 | agadez
# Processing Record 29 of Set 8 | south huntington
# Processing Record 30 of Set 8 | muroto
# Processing Record 31 of Set 8 | alma
# Processing Record 32 of Set 8 | grindavik
# Processing Record 33 of Set 8 | maceio
# City not found. Skipping ...
# Processing Record 34 of Set 8 | peski
# Processing Record 35 of Set 8 | santa vitoria do palmar
# Processing Record 36 of Set 8 | nkhotakota
# City not found. Skipping ...
# Processing Record 37 of Set 8 | la union
# Processing Record 38 of Set 8 | shakawe
# City not found. Skipping ...
# Processing Record 39 of Set 8 | jimeta
# Processing Record 40 of Set 8 | byron bay
# Processing Record 41 of Set 8 | durban
# Processing Record 42 of Set 8 | ravar
# Processing Record 43 of Set 8 | victor harbor
# Processing Record 44 of Set 8 | tocopilla
# Processing Record 45 of Set 8 | moree
# Processing Record 46 of Set 8 | parrita
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 47 of Set 8 | san quintin
# Processing Record 48 of Set 8 | kem
# Processing Record 49 of Set 8 | coihaique
# Processing Record 50 of Set 8 | grand baie
# Processing Record 1 of Set 9 | havre-saint-pierre
# Processing Record 2 of Set 9 | santa elena
# Processing Record 3 of Set 9 | tarko-sale
# Processing Record 4 of Set 9 | paragominas
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 5 of Set 9 | preobrazheniye
# Processing Record 6 of Set 9 | missouri city
# Processing Record 7 of Set 9 | pizarro
# City not found. Skipping ...
# Processing Record 8 of Set 9 | kon tum
# Processing Record 9 of Set 9 | kijang
# Processing Record 10 of Set 9 | egvekinot
# Processing Record 11 of Set 9 | johnstown
# City not found. Skipping ...
# Processing Record 12 of Set 9 | oranjestad
# Processing Record 13 of Set 9 | ngunguru
# Processing Record 14 of Set 9 | belen
# Processing Record 15 of Set 9 | bilibino
# Processing Record 16 of Set 9 | bay roberts
# Processing Record 17 of Set 9 | waldkraiburg
# Processing Record 18 of Set 9 | oroville
# Processing Record 19 of Set 9 | port moresby
# City not found. Skipping ...
# Processing Record 20 of Set 9 | diego de almagro
# Processing Record 21 of Set 9 | georgiyevka
# Processing Record 22 of Set 9 | nong bua
# Processing Record 23 of Set 9 | mapiri
# Processing Record 24 of Set 9 | nara
# Processing Record 25 of Set 9 | khash
# Processing Record 26 of Set 9 | guerrero negro
# Processing Record 27 of Set 9 | port hedland
# Processing Record 28 of Set 9 | olpad
# Processing Record 29 of Set 9 | axim
# Processing Record 30 of Set 9 | puerto escondido
# Processing Record 31 of Set 9 | springbok
# Processing Record 32 of Set 9 | georgiyevskoye
# Processing Record 33 of Set 9 | pore
# Processing Record 34 of Set 9 | sahuaripa
# City not found. Skipping ...
# Processing Record 35 of Set 9 | tautira
# Processing Record 36 of Set 9 | port blair
# Processing Record 37 of Set 9 | fengcheng
# City not found. Skipping ...
# Processing Record 38 of Set 9 | quartucciu
# Processing Record 39 of Set 9 | novska
# Processing Record 40 of Set 9 | amberley
# Processing Record 41 of Set 9 | sprimont
# Processing Record 42 of Set 9 | bud
# Processing Record 43 of Set 9 | rodrigues alves
# Processing Record 44 of Set 9 | cockburn town
# Processing Record 45 of Set 9 | homer
# Processing Record 46 of Set 9 | rosetta
# Processing Record 47 of Set 9 | svetlogorsk
# Processing Record 48 of Set 9 | raymond terrace
# Processing Record 49 of Set 9 | neuquen
# Processing Record 50 of Set 9 | grand forks
# Processing Record 1 of Set 10 | port lavaca
# Processing Record 2 of Set 10 | buarcos
# City not found. Skipping ...
# Processing Record 3 of Set 10 | muyezerskiy
# Processing Record 4 of Set 10 | micheweni
# Processing Record 5 of Set 10 | olga
# Processing Record 6 of Set 10 | yola
# Processing Record 7 of Set 10 | carora
# Processing Record 8 of Set 10 | fare
# Processing Record 9 of Set 10 | codrington
# Processing Record 10 of Set 10 | banda aceh
# Processing Record 11 of Set 10 | dwarka
# Processing Record 12 of Set 10 | lethem
# Processing Record 13 of Set 10 | southampton
# Processing Record 14 of Set 10 | altay
# Processing Record 15 of Set 10 | carballo
# Processing Record 16 of Set 10 | sumkino
# Processing Record 17 of Set 10 | robore
# Processing Record 18 of Set 10 | kysyl-syr
# Processing Record 19 of Set 10 | zyryanka
# Processing Record 20 of Set 10 | capim grosso
# Processing Record 21 of Set 10 | ixtapa
# Processing Record 22 of Set 10 | jacqueville
# Processing Record 23 of Set 10 | yaan
# Processing Record 24 of Set 10 | palanga
# Processing Record 25 of Set 10 | marquette
# City not found. Skipping ...
# Processing Record 26 of Set 10 | kuryk
# Processing Record 27 of Set 10 | saint-louis
# Processing Record 28 of Set 10 | constitucion
# Processing Record 29 of Set 10 | verkhnevilyuysk
# City not found. Skipping ...
# Processing Record 30 of Set 10 | gornopravdinsk
# Processing Record 31 of Set 10 | sazonovo
# Processing Record 32 of Set 10 | selty
# City not found. Skipping ...
# Processing Record 33 of Set 10 | plastun
# Processing Record 34 of Set 10 | maralal
# Processing Record 35 of Set 10 | elizabeth city
# Processing Record 36 of Set 10 | matara
# Processing Record 37 of Set 10 | yerbogachen
# Processing Record 38 of Set 10 | aboisso
# Processing Record 39 of Set 10 | tura
# Processing Record 40 of Set 10 | wanning
# Processing Record 41 of Set 10 | mega
# Processing Record 42 of Set 10 | fecamp
# Processing Record 43 of Set 10 | kerema
# Processing Record 44 of Set 10 | klaksvik
# Processing Record 45 of Set 10 | balclutha
# Processing Record 46 of Set 10 | mezhevoy
# Processing Record 47 of Set 10 | mutare
# Processing Record 48 of Set 10 | luderitz
# City not found. Skipping ...
# Processing Record 49 of Set 10 | trofors
# Processing Record 50 of Set 10 | panguna
# Processing Record 1 of Set 11 | manta
# Processing Record 2 of Set 11 | mudkhed
# Processing Record 3 of Set 11 | nantucket
# Processing Record 4 of Set 11 | nemuro
# Processing Record 5 of Set 11 | okhotsk
# City not found. Skipping ...
# Processing Record 6 of Set 11 | papillion
# Processing Record 7 of Set 11 | pandan
# Processing Record 8 of Set 11 | half moon bay
# City not found. Skipping ...
# Processing Record 9 of Set 11 | roald
# Processing Record 10 of Set 11 | joao pinheiro
# City not found. Skipping ...
# Processing Record 11 of Set 11 | saint-georges
# Processing Record 12 of Set 11 | arroyohondo
# Processing Record 13 of Set 11 | cherepovets
# Processing Record 14 of Set 11 | puerto baquerizo moreno
# Processing Record 15 of Set 11 | annaka
# Processing Record 16 of Set 11 | kavaratti
# Processing Record 17 of Set 11 | moose factory
# Processing Record 18 of Set 11 | beloha
# Processing Record 19 of Set 11 | high level
# Processing Record 20 of Set 11 | del rio
# Processing Record 21 of Set 11 | mount isa
# Processing Record 22 of Set 11 | ouadda
# Processing Record 23 of Set 11 | prokuplje
# Processing Record 24 of Set 11 | reconquista
# Processing Record 25 of Set 11 | shelbyville
# City not found. Skipping ...
# Processing Record 26 of Set 11 | sobolevo
# Processing Record 27 of Set 11 | genhe
# Processing Record 28 of Set 11 | bama
# Processing Record 29 of Set 11 | gualaquiza
# Processing Record 30 of Set 11 | poltava
# Processing Record 31 of Set 11 | takoradi
# Processing Record 32 of Set 11 | imeni zhelyabova
# Processing Record 33 of Set 11 | palauig
# Processing Record 34 of Set 11 | mao
# Processing Record 35 of Set 11 | lazaro cardenas
# Processing Record 36 of Set 11 | bambanglipuro
# Processing Record 37 of Set 11 | makat
# Processing Record 38 of Set 11 | cruzeiro do sul
# Processing Record 39 of Set 11 | khandbari
# Processing Record 40 of Set 11 | masyaf
# Processing Record 41 of Set 11 | atar
# Processing Record 42 of Set 11 | conceicao do araguaia
# Processing Record 43 of Set 11 | inuvik
# Processing Record 44 of Set 11 | pedernales
# Processing Record 45 of Set 11 | sosnovo-ozerskoye
# Processing Record 46 of Set 11 | anadyr
# Processing Record 47 of Set 11 | tayoltita
# Processing Record 48 of Set 11 | smithers
# Processing Record 49 of Set 11 | bathsheba
# Processing Record 50 of Set 11 | nanakuli
# Processing Record 1 of Set 12 | salalah
# Processing Record 2 of Set 12 | fuyang
# Processing Record 3 of Set 12 | ugoofaaru
# Processing Record 4 of Set 12 | loikaw
# Processing Record 5 of Set 12 | shahr-e babak
# Processing Record 6 of Set 12 | dolinsk
# Processing Record 7 of Set 12 | talnakh
# Processing Record 8 of Set 12 | soledad
# Processing Record 9 of Set 12 | novosheshminsk
# Processing Record 10 of Set 12 | leesburg
# ------------------------------
#
# Data Retrieval Complete
#
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Generate weather data frame
weather_df = pd.DataFrame({"City": city_list,
                           "Cloudiness" : cloud_list,
                           "Country": country_list,
                           "Date": date_list,
                           "Humidity" : humidity_list,
                           "Lat": lat_list,
                           "Lng":lng_list,
                            "Max Temp": maxtemp_list,
                            "Wind Speed": windspeed_list
                           })

weather_df.count()
# Out:
# City          560
# Cloudiness    560
# Country       560
# Date          560
# Humidity      560
# Lat           560
# Lng           560
# Max Temp      560
# Wind Speed    560
# dtype: int64

# %%
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Yellowknife          75      CA  1571534907        80  62.45 -114.38
# 1     Katsuura          75      JP  1571534891        64  33.93  134.50
# 2     Cidreira         100      BR  1571535406        82 -30.17  -50.22
# 3     Thompson          90      CA  1571535406        75  55.74  -97.86
# 4     Ucluelet          20      CA  1571535406        87  48.94 -125.55
#
#    Max Temp  Wind Speed
# 0     30.20        8.05
# 1     71.60       14.99
# 2     56.11        4.54
# 3     41.00        8.05
# 4     52.00        9.17

# %%
#save data frame to csv
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (10/19/2019)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude vs. Temperature Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(10/19/2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude vs. Humidity Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness(10/19/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Cloudiness Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed(10/19/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# ### Analysis
# * The temperature of cities near equator are typically warmer
# * The cities in northern hemisphere has a relative higher humidity than southern hemisphere
# * The cities in northern hemisphere has a relative higher cloudiness than southern hemisphere
# * Most cities wind speed range is between 0-15mph
