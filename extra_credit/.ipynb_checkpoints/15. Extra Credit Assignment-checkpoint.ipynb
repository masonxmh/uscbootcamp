# %% [markdown]
# <div class="jumbotron jumbotron-fluid">
#   <div class="container">
#     <h1 class="display-4">Having Fun with Python: World Population Analysis</h1>
#     <p class="lead">Extra Credit Homework Assignment</p>
#
#   </div>
# </div>
#
# <div class="card mb-3" style="max-width: 540px;">
#   <div class="row no-gutters">
#     <div class="col-md-4">
#       <img src="Data/English/Scanned_documents/t2.tif" class="card-img" alt="...">
#     </div>
#     <div class="col-md-8">
#       <div class="card-body">
#         <h5 class="card-title">Task</h5>
#         <p class="card-text">Extract data from a "World Population" PDF. unfortunately the client was only able to obtain a copy of the data and no time to request another format. Analysis needs to be done using Python Pandas</p>
#         <p class="card-text"><small class="text-muted">Use: Pandas, Regex, and Plotting</small></p>
#       </div>
#     </div>
#   </div>
# </div>
#
#
# Overall Steps:
# * Convert image data to string (OCR)
# * User Regex for Data Cleanup and Extraction
# * Convert data to a Pandas DataFrame
# * Plotting
# * Final Analysis

# %% [markdown]
# # 1. Load Our Libraries
#
# Before we start let's make sure we have all the libraries installed and loaded. If you don't have these installed from a prior exercise you can run from your terminal
#
# ```bash
# pip install -r requirements.txt
# ```
#
# or
#
#
# ```bash
# conda install --yes -c conda-forge --file requirements.txt
# ```
#
# In this assignment we wil be using:
# * `tabula`: is actually a python wrapper to `tabula java` which a library for extracting tables from PDF files
# * `pytesseract`: Python-tesseract is a wrapper for [Google's Tesseract-OCR Engine](https://github.com/tesseract-ocr/tesseract).
# * `PIL`: Python Imaging Library (PIL) adds image processing capabilities to your Python interpreter. This library supports many file formats, and provides powerful image processing and graphics capabilities.
# * `pandas`: Easy-to-use data structures and data analysis tools in Python
# * `re`:  a Python module which provides regular expression matching operations

# %%
# conda install --yes -c conda-forge --file requirements.txt

# %%
import pdf2image
import tabula
import pytesseract
import PIL
import pandas as pd
import re
import os
# import img2pdf

# %% [markdown]
# ## Let's explore `tabula` library and see it is used in general
# * `tabula.environment_info()` shows environment information for reporting. Returns detailed information like Python version, Java version, or OS environment, etc. Let's see it in action:

# %%
tabula.environment_info()
# Out:
# Python version:
#     3.7.5 (default, Oct 31 2019, 15:18:51) [MSC v.1916 64 bit (AMD64)]
# Java version:
#     java version "1.8.0_231"
# Java(TM) SE Runtime Environment (build 1.8.0_231-b11)
# Java HotSpot(TM) Client VM (build 25.231-b11, mixed mode)
# tabula-py version: 1.4.3
# platform: Windows-10-10.0.17134-SP0
# uname:
#     uname_result(system='Windows', node='DESKTOP-AJGSTPP', release='10', version='10.0.17134', machine='AMD64', processor='Intel64 Family 6 Model 94 Stepping 3, GenuineIntel')
# linux_distribution: ('MINGW64_NT-10.0-17134', '3.0.7', '')
# mac_ver: ('', ('', '', ''), '')

# %% [markdown]
# ### Use `tabula` to read a PDF file and convert it into a `panda.DataFrame`
# Example: We have `Q3 FY19 Consolidated Financial Statements.pdf` which is Apple's latest Financial Report, which has multiple pages. By default, tabula will read the first page, which is fine for our testing. Let's see it in action before we run it on `worldpopulation.pdf` since this financial statement is nicely formatted and gives us a feeling on how this library works.

# %%
apple_df = tabula.read_pdf("Data/Q3 FY19 Consolidated Financial Statements.pdf")
apple_df.head()
# Out:
#             Unnamed: 0 Unnamed: 1  June 29,  Unnamed: 3  June 30,  Unnamed: 5  \
# 0                  NaN        NaN      2019         NaN      2018         NaN
# 1           Net sales:        NaN       NaN         NaN       NaN         NaN
# 2             Products          $  42,354 $         NaN  43,095 $         NaN
# 3             Services        NaN    11,455         NaN    10,170         NaN
# 4  Total net sales (1)        NaN    53,809         NaN    53,265         NaN
#
#   June 29,.1  Unnamed: 7 June 30,.1
# 0       2019         NaN       2018
# 1        NaN         NaN        NaN
# 2  162,354 $         NaN    173,546
# 3     33,780         NaN     29,149
# 4    196,134         NaN    202,695

# %% [markdown]
# The headers are not correct, and we probably need to make some adjustments. If we examing the documentation we see `pandas_options={'header': None}` option. Let's give it try:

# %%
apple_df = tabula.read_pdf("Data/Q3 FY19 Consolidated Financial Statements.pdf", pandas_options={'header':None})
apple_df.head(10)
# Out:
#                      0    1         2   3         4   5          6   7  \
# 0                  NaN  NaN  June 29, NaN  June 30, NaN   June 29, NaN
# 1                  NaN  NaN      2019 NaN      2018 NaN       2019 NaN
# 2           Net sales:  NaN       NaN NaN       NaN NaN        NaN NaN
# 3             Products    $  42,354 $ NaN  43,095 $ NaN  162,354 $ NaN
# 4             Services  NaN    11,455 NaN    10,170 NaN     33,780 NaN
# 5  Total net sales (1)  NaN    53,809 NaN    53,265 NaN    196,134 NaN
# 6       Cost of sales:  NaN       NaN NaN       NaN NaN        NaN NaN
# 7             Products  NaN    29,473 NaN    28,956 NaN    109,758 NaN
# 8             Services  NaN     4,109 NaN     3,888 NaN     12,297 NaN
# 9  Total cost of sales  NaN    33,582 NaN    32,844 NaN    122,055 NaN
#
#           8
# 0  June 30,
# 1      2018
# 2       NaN
# 3   173,546
# 4    29,149
# 5   202,695
# 6       NaN
# 7   113,467
# 8    11,473
# 9   124,940

# %% [markdown]
# We diffentely need to do more work to clean this up. But this is not our task, we need to read `worldpopulation.pdf`.
#
# ## Q1: Use `tabula` to read and convert the pdf into a dataframe (5pts)

# %%
import os

def pdf2panda(file):
    ## Your code
    df=tabula.read_pdf(file)
    
    
    return df

# %%
#Test Data/English/Scanned_documents/worldpopulations.pdf
file = os.path.join("Data", "English", "Scanned_documents", "worldpopulations.pdf")
output = pdf2panda(file)
print(output)
# Out:
# The output file is empty.
# None

# %% [markdown]
# If the output says `file is empty` then we know `tabula` is not a good choice. Mainly, because this PDF obiously was created from an image which means we need to figure out other options

# %% [markdown]
# # 2. Extracting our Text
#
# ## Explore other options with `pytesseract`
# To use `pytesseract` OCR we first need to convert ther PDF to an image, and then use the OCR to extract text from that image.
#
# * We will use `pdf2image` library to convert the PDF into an image
# * Use `pytesseract` to extract text from that image
#
# Let's try this using the Apple data for a test run.

# %%
pages = pdf2image.convert_from_path("Data/Q3 FY19 Consolidated Financial Statements.pdf")
for page in pages:
    page.save('apple.jpg', 'JPEG')

# %% [markdown]
# To validate we can open the image using `PIL.Image.open` as in below:

# %%
PIL.Image.open('apple.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1700x2200 at 0x1E6490B2248>

# %% [markdown]
# Generally, `pdf2image` returns a PIL iterable object. We can actually pass it directly to `pytesseract` and skip the need to save that image. Let's see that in action:

# %%
# add this line for tesseract to work for windows
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"
pages = pdf2image.convert_from_path("Data/Q3 FY19 Consolidated Financial Statements.pdf")
for content in pages:
    print(pytesseract.image_to_string(content))
# Out:
# Apple Inc.
#
# CONDENSED CONSOLIDATED STATEMENTS OF OPERATIONS (Unaudited)
# (In millions, except number of shares which are reflected in thousands and per share amounts)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Three Months Ended Nine Months Ended
# June 29, June 30, June 29, June 30,
# 2019 2018 2019 2018
# Net sales:
# Products $ 42,354 $ 43,095 $ 162,354 $ 173,546
# Services 11,455 10,170 33,780 29,149
# Total net sales “) 53,809 53,265 196,134 202,695
# Cost of sales:
# Products 29,473 28,956 109,758 113,467
# Services 4,109 3,888 12,297 11,473
# Total cost of sales 33,582 32,844 122,055 124,940
# Gross margin 20,227 20,421 74,079 77,755
# Operating expenses:
# Research and development 4,257 3,701 12,107 10,486
# Selling, general and administrative 4,426 4,108 13,667 12,489
# Total operating expenses 8,683 7,809 25,774 22,975
# Operating income 11,544 12,612 48,305 54,780
# Other income/(expense), net 367 672 1,305 1,702
# Income before provision for income taxes 11,911 13,284 49,610 56,482
# Provision for income taxes 1,867 1,765 8,040 11,076
# Net income $ 10,044 $ 11,519 $ 41,570 $ 45,406
# Earnings per share:
# Basic $ 2.20 $ 2.36 $ 8.92 $ 9.07
# Diluted $ 2.18 $ 2.34 $ 8.86 $ 8.99
# Shares used in computing earnings per share:
# Basic 4,570,633 4,882,167 4,660,175 5,006,640
# Diluted 4,601,380 4,926,609 4,691,759 5,050,963
# () Net sales by reportable segment:
# Americas $ 25,056 $ 24,542 $ 87,592 $ 84,576
# Europe 11,925 12,138 45,342 47,038
# Greater China 9,157 9,551 32,544 40,531
# Japan 4,082 3,867 16,524 16,572
# Rest of Asia Pacific 3,589 3,167 14,132 13,978
# Total net sales $ 53,809 $ 53,265 $ 196,134 $ 202,695
# (“) Net sales by category:
# iPhone $ 25,986 $ 29,470 $ 109,019 $ 128,133
# Mac 5,820 5,258 18,749 17,858
# iPad 5,023 4,634 16,624 14,397
# Wearables, Home and Accessories 5,525 3,733 17,962 13,158
# Services 11,455 10,170 33,780 29,149
#
# Total net sales $ 53,809 $ 53,265 $ 196,134 $ 202,695
# Apple Inc.
#
# CONDENSED CONSOLIDATED BALANCE SHEETS (Unaudited)
# (In millions, except number of shares which are reflected in thousands and par value)
#
# June 29, September 29,
# 2019 2018
# ASSETS:
# Current assets:
# Cash and cash equivalents $ 50,530 $ 25,913
# Marketable securities 44,084 40,388
# Accounts receivable, net 14,148 23,186
# Inventories 3,355 3,956
# Vendor non-trade receivables 12,326 25,809
# Other current assets 10,530 12,087
# Total current assets 134,973 131,339
# Non-current assets:
# Marketable securities 115,996 170,799
# Property, plant and equipment, net 37,636 41,304
# Other non-current assets 33,634 22,283
# Total non-current assets 187,266 234,386
# Total assets $ 322,239 $ 365,725
# LIABILITIES AND SHAREHOLDERS’ EQUITY:
# Current liabilities:
# Accounts payable $ 29,115 $ 55,888
# Other current liabilities 31,673 33,327
# Deferred revenue 5,434 5,966
# Commercial paper 9,953 11,964
# Term debt 13,529 8,784
# Total current liabilities 89,704 115,929
# Non-current liabilities:
# Term debt 84,936 93,735
# Other non-current liabilities 51,143 48,914
# Total non-current liabilities 136,079 142,649
# Total liabilities 225,783 258,578
# Commitments and contingencies
# Shareholders’ equity:
# Common stock and additional paid-in capital, $0.00001 par value: 12,600,000 shares
# authorized; 4,531,395 and 4,754,986 shares issued and outstanding, respectively 43,371 40,201
# Retained earnings 53,724 70,400
# Accumulated other comprehensive income/(loss) (639) (3,454)
# Total shareholders’ equity 96,456 107,147
#
# Total liabilities and shareholders’ equity $ 322,239 $ 365,725
# Apple Inc.
#
# CONDENSED CONSOLIDATED STATEMENTS OF CASH FLOWS (Unaudited)
#
# (In millions)
# Nine Months Ended
# June 29, June 30,
# 2019 2018
# Cash, cash equivalents and restricted cash, beginning balances $ 25,913 $ 20,289
# Operating activities:
# Net income 41,570 45,406
# Adjustments to reconcile net income to cash generated by operating activities:
# Depreciation and amortization 9,368 8,149
# Share-based compensation expense 4,569 3,995
# Deferred income tax benefit (38) (33,109)
# Other (340) (410)
# Changes in operating assets and liabilities:
# Accounts receivable, net 9,013 3,756
# Inventories 496 (1,114)
# Vendor non-trade receivables 13,483 5,536
# Other current and non-current assets 693 (65)
# Accounts payable (19,804) (10,410)
# Deferred revenue (776) (73)
# Other current and non-current liabilities (8,753) 36,250
# Cash generated by operating activities 49,481 57,911
# Investing activities:
# Purchases of marketable securities (21,902) (56,133)
# Proceeds from maturities of marketable securities 26,783 46,290
# Proceeds from sales of marketable securities 49,516 41,614
# Payments for acquisition of property, plant and equipment (7,718) (10,272)
# Payments made in connection with business acquisitions, net (611) (431)
# Purchases of non-marketable securities (632) (1,788)
# Proceeds from non-marketable securities 1,526 310
# Other (268) (523)
# Cash generated by investing activities 46,694 19,067
# Financing activities:
# Proceeds from issuance of common stock 391 328
# Payments for taxes related to net share settlement of equity awards (2,626) (2,267)
# Payments for dividends and dividend equivalents (10,640) (10,182)
# Repurchases of common stock (49,453) (53,634)
# Proceeds from issuance of term debt, net _ 6,969
# Repayments of term debt (5,500) (6,500)
# Repayments of commercial paper, net (2,026) (10)
# Other (83) =
# Cash used in financing activities (69,937) (65,296)
# Increase in cash, cash equivalents and restricted cash 26,238 11,682
# Cash, cash equivalents and restricted cash, ending balances $ 52,151 $ 31,971
# Supplemental cash flow disclosure:
# Cash paid for income taxes, net $ 11,795 $ 8,819
# Cash paid for interest $ 2,563 $ 2,120

# %% [markdown]
# ## Q2: Write a function that converts a PDF into an image and then pass it to the OCR. The function should return a list (5 pts)

# %%
def convertPDF(pdffile):
    ## ADD YOUR CODE
    pages = pdf2image.convert_from_path(pdffile)
    datalist = []
    for content in pages:
        datalist.append(pytesseract.image_to_string(content))
    
    ## return a python list that contains data extract per page
    
    return datalist

# %%
#test 1
file = os.path.join("Data", "Q3 FY19 Consolidated Financial Statements.pdf")
imagesdata = convertPDF(file)
print(f'number of images processed = {len(imagesdata)}')
print(imagesdata)
# Out:
# number of images processed = 3
# ['Apple Inc.\n\nCONDENSED CONSOLIDATED STATEMENTS OF OPERATIONS (Unaudited)\n(In millions, except number of shares which are reflected in thousands and per share amounts)\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nThree Months Ended Nine Months Ended\nJune 29, June 30, June 29, June 30,\n2019 2018 2019 2018\nNet sales:\nProducts $ 42,354 $ 43,095 $ 162,354 $ 173,546\nServices 11,455 10,170 33,780 29,149\nTotal net sales “) 53,809 53,265 196,134 202,695\nCost of sales:\nProducts 29,473 28,956 109,758 113,467\nServices 4,109 3,888 12,297 11,473\nTotal cost of sales 33,582 32,844 122,055 124,940\nGross margin 20,227 20,421 74,079 77,755\nOperating expenses:\nResearch and development 4,257 3,701 12,107 10,486\nSelling, general and administrative 4,426 4,108 13,667 12,489\nTotal operating expenses 8,683 7,809 25,774 22,975\nOperating income 11,544 12,612 48,305 54,780\nOther income/(expense), net 367 672 1,305 1,702\nIncome before provision for income taxes 11,911 13,284 49,610 56,482\nProvision for income taxes 1,867 1,765 8,040 11,076\nNet income $ 10,044 $ 11,519 $ 41,570 $ 45,406\nEarnings per share:\nBasic $ 2.20 $ 2.36 $ 8.92 $ 9.07\nDiluted $ 2.18 $ 2.34 $ 8.86 $ 8.99\nShares used in computing earnings per share:\nBasic 4,570,633 4,882,167 4,660,175 5,006,640\nDiluted 4,601,380 4,926,609 4,691,759 5,050,963\n() Net sales by reportable segment:\nAmericas $ 25,056 $ 24,542 $ 87,592 $ 84,576\nEurope 11,925 12,138 45,342 47,038\nGreater China 9,157 9,551 32,544 40,531\nJapan 4,082 3,867 16,524 16,572\nRest of Asia Pacific 3,589 3,167 14,132 13,978\nTotal net sales $ 53,809 $ 53,265 $ 196,134 $ 202,695\n(“) Net sales by category:\niPhone $ 25,986 $ 29,470 $ 109,019 $ 128,133\nMac 5,820 5,258 18,749 17,858\niPad 5,023 4,634 16,624 14,397\nWearables, Home and Accessories 5,525 3,733 17,962 13,158\nServices 11,455 10,170 33,780 29,149\n\nTotal net sales $ 53,809 $ 53,265 $ 196,134 $ 202,695', 'Apple Inc.\n\nCONDENSED CONSOLIDATED BALANCE SHEETS (Unaudited)\n(In millions, except number of shares which are reflected in thousands and par value)\n\nJune 29, September 29,\n2019 2018\nASSETS:\nCurrent assets:\nCash and cash equivalents $ 50,530 $ 25,913\nMarketable securities 44,084 40,388\nAccounts receivable, net 14,148 23,186\nInventories 3,355 3,956\nVendor non-trade receivables 12,326 25,809\nOther current assets 10,530 12,087\nTotal current assets 134,973 131,339\nNon-current assets:\nMarketable securities 115,996 170,799\nProperty, plant and equipment, net 37,636 41,304\nOther non-current assets 33,634 22,283\nTotal non-current assets 187,266 234,386\nTotal assets $ 322,239 $ 365,725\nLIABILITIES AND SHAREHOLDERS’ EQUITY:\nCurrent liabilities:\nAccounts payable $ 29,115 $ 55,888\nOther current liabilities 31,673 33,327\nDeferred revenue 5,434 5,966\nCommercial paper 9,953 11,964\nTerm debt 13,529 8,784\nTotal current liabilities 89,704 115,929\nNon-current liabilities:\nTerm debt 84,936 93,735\nOther non-current liabilities 51,143 48,914\nTotal non-current liabilities 136,079 142,649\nTotal liabilities 225,783 258,578\nCommitments and contingencies\nShareholders’ equity:\nCommon stock and additional paid-in capital, $0.00001 par value: 12,600,000 shares\nauthorized; 4,531,395 and 4,754,986 shares issued and outstanding, respectively 43,371 40,201\nRetained earnings 53,724 70,400\nAccumulated other comprehensive income/(loss) (639) (3,454)\nTotal shareholders’ equity 96,456 107,147\n\nTotal liabilities and shareholders’ equity $ 322,239 $ 365,725', 'Apple Inc.\n\nCONDENSED CONSOLIDATED STATEMENTS OF CASH FLOWS (Unaudited)\n\n(In millions)\nNine Months Ended\nJune 29, June 30,\n2019 2018\nCash, cash equivalents and restricted cash, beginning balances $ 25,913 $ 20,289\nOperating activities:\nNet income 41,570 45,406\nAdjustments to reconcile net income to cash generated by operating activities:\nDepreciation and amortization 9,368 8,149\nShare-based compensation expense 4,569 3,995\nDeferred income tax benefit (38) (33,109)\nOther (3 ...

# %%
# test 2
file = os.path.join("Data", "English", "Scanned_documents", "worldpopulations.pdf")
imagesdata = convertPDF(file)
print(f'number of images processed = {len(imagesdata)}')
print(imagesdata)
# Out:
# number of images processed = 1
# ['Demographic data and estimates Area, Density, Capital City\n\n \n\n \n\n \n\n \n\nProjected — Percent of Life\nPopulation Population Population of Expectancy Pop. per\nMid-2002 (millions) Age at Birth area of Countries Square\n(millions) 2025 «<15.—s« 65+ (years) (square miles) Mile Capital City\nWORLD 6215 7,859 30 7 ea 51,789,601 120\n| 1197 1.249 18 15 76 19,814,584 60\n5.018 661 33 5 65 31,975,017 157\n= 741.2 96.1 36 4 66 386,66 184 Cairo\npaul 129.9 2045 44 3 52 356,668 364 Abuja\nS = ez 117.6 BANS 52 426,371 159 Addis Ababa\nrn wz 37.2 598 45. 3 52 364,9 102 Dodoma\na 55.2 106.0 48 3 49 905,351 61 Kinshasa\n= 43.6 35.1 34.5 51 471,444 93 Pretoria\nI¥l 31.3 36.0 19 13 79 3,849,670 8 Ottawa\n< 2874 346.0 21. 13 77 3,717,796 77 Washington, DC\nz Le 101.7 131.7 33.5 75 756,062 135 Mexico Cit\nFo 36.5 47.2 28 10 74 1,073,514 34 Buenos Aires\n< fs) 173.8 219.0 30 6 69 3,300,154 53 ___ Brasilia\nmem | Colombia 43.8 50.7 33.5 71 439,734. 100 Bogota\n32 40 25 10 75 3,306,741 10\n‘e 1336 1778 40 3 59 55,598 2,403 Dhaka\n= | india 1,049.5 1,363.0 36 4 63 1,269,340 827___ New Delhi\n143.5. 2421 42.4 63 307,375 467 _Islamabad\n< i 217.0 2819 31. 5 68 735,355 295 _ Jakarta\n| Philippines 80.0 1155 37. 4 68 115,83 691___ Manila\n= 797. 1041 31. 6 68 128,066 622 Hanoi\n= 1,280.7 1454.7 23 7 71 3,696,100 347_Beijing\n@ | Japan 1274. 1211 14. 18 81 145,869 873 Tokyo\n== 60.2 64.8 19 16 78 94,548 637 London\n< LL 59.5 64.2 19 16 79 212,934. 279 Paris\n© i 82.4 78.14 16 16 78 137,83. 598 Berlin\nA 143.5 1291 18 13 65 6,592,819 22 Moscow\naa 58.1 575 14 19 80 116,32 499 Rome']

# %% [markdown]
# ## Q3: Display the image (5 pts)
# We also have the image in a higher resolution format. After investigating the quality of the OCR above (notice for example Egypt and some countries are missing), is that the PDF was actually created from an Image. So convering back to an image reduced the quality. Let's examine the image that the analyst forgot to share with us.

# %%
file = os.path.join("Data", "English", "Scanned_documents", "t2.tif")
## YOUR CODE HERE
print (PIL.PILLOW_VERSION)
PIL.Image.open(file)
# Out:
# 6.2.1
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=3306x4677 at 0x1E6490E4308>

# %% [markdown]
# We will apply OCR again and compare the quality of the outcoome

# %%
data = pytesseract.image_to_string(file)
data
# Out:
# 'Demographic data and estimates Area, Density, Capital City\n\n \n\n \n\n \n\n \n\n \n\n \n\nVat e7.\n\n \n\n \n\n€\n\n \n\n \n\n \n\n \n\nAMERICA\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nASIA\n\n \n\n \n\n \n\nHOM IGHE PONSA\n\n \n\nNY\n“iit\n\n \n\n \n\n \n\nEUROPA\nIi\n\n \n\n \n\nProjected Percent of Life\n\nPopulation Population Population of Expectancy Pop. per\n\nMid-2002 ~=—(millions) Age at Birth Area of Countries Square\n\n(millions) 2025 <15 65+ (years) (square miles) Mile Capital City\nWORLD 6,215 7,859 30 7 oy 4 51,789,601 120\nMORE DEVELOPED 1,197 1.249 18 15 76 19,814,584 60\nLESS DEVELOPED 5.018 6,61 33 5 65 31,975,017 157\nEgypt 11.2 96.1 36 4 66 386,66 184 Cairo\nNigeria 129.9 204.5 44 o 52 356,668 364 Abuja\nEthiopia 67.7 117.6 44 3 52 426,371 159 Addis Ababa\nTanzania 37.2 59.8 45 3 52 364,9 102 Dodoma\nCongo, Dem. Rep. of 562 106.0 48 3 49 905,351 61 Kinshasa\nSouth Africa 43.6 35.1 34 5 51 471,444 93 Pretoria\nCanada 31.3 36.0 19 13 79 3,849,670 8 Ottawa\nUnited States 287.4 346.0 21 13 77 3,/17,796 77 Washington, DC\nMexico 101.7 131.7 33 5 75 756,062 135 Mexico City\nArgentina 36.5 47.2 28 10 74 1,073,514 34 Buenos Aires\nBrazil 173.8 219.0 30 6 69 3,300,154 53 Brasilia\nColombia 43.8 59.7 33 o 71 439,734 100 Bogota\nAustralia & Oceania 32 40 25 10 75 3,306,741 10\nBangladesh 133.6 177.8 40 3 59 55,598 2,403 Dhaka\nIndia 1,049.5 1,363.0 36 4 63 1,269,340 827 New Delhi\nPakistan 143.5 242.1 42 4 63 307,375 467 Islamabad\nIndonesia 217.0 281.9 31 5 68 735,355 295 Jakarta\nPhilippines 80.0 115.5 37 4 68 115,83 691 Manila\nVietnam 19.7 104.1 31 6 68 128,066 622 Hanoi\nChina 1,280.7 1,454.7 23 7 71 3,696,100 347 Beijing\nJapan 127.4 121.1 14 18 81 145,869 873 Tokyo\nUnited Kingdom 60.2 64.8 19 16 78 94,548 637 London\nFrance 59.5 64.2 19 16 79 212,934 279 Paris\nGermany 82.4 78.1 16 16 78 137,83 598 Berlin\nRussia 143.5 129.1 18 13 65 6,592,819 22 Moscow\nItaly 58.1 57.5 14 19 80 116,32 499 Rome'

# %% [markdown]
# ## Q4 was there any difference? (5 pts)
# Compare the length between the two outputs. Which one was higher?

# %%
output_tif=len(data)
f'output from TIF format = {output_tif}'
# Out:
# 'output from TIF format = 1834'

# %%
#pdf file data
output_pdf=len(imagesdata[0])
f'output from PDF format = {output_pdf}'
# Out:
# 'output from PDF format = 1545'

# %% [markdown]
# ## 3. Extracting data into a DataFrame
# We can see there is a lot of `\n`, in order to view it in an easier to read format we can use print. Remember, this is a python list that we got back.

# %%
print(data)
# Out:
# Demographic data and estimates Area, Density, Capital City
#
#
#
#
#
#
#
#
#
#
#
#
#
# Vat e7.
#
#
#
#
#
# €
#
#
#
#
#
#
#
#
#
# AMERICA
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ASIA
#
#
#
#
#
#
#
# HOM IGHE PONSA
#
#
#
# NY
# “iit
#
#
#
#
#
#
#
# EUROPA
# Ii
#
#
#
#
#
# Projected Percent of Life
#
# Population Population Population of Expectancy Pop. per
#
# Mid-2002 ~=—(millions) Age at Birth Area of Countries Square
#
# (millions) 2025 <15 65+ (years) (square miles) Mile Capital City
# WORLD 6,215 7,859 30 7 oy 4 51,789,601 120
# MORE DEVELOPED 1,197 1.249 18 15 76 19,814,584 60
# LESS DEVELOPED 5.018 6,61 33 5 65 31,975,017 157
# Egypt 11.2 96.1 36 4 66 386,66 184 Cairo
# Nigeria 129.9 204.5 44 o 52 356,668 364 Abuja
# Ethiopia 67.7 117.6 44 3 52 426,371 159 Addis Ababa
# Tanzania 37.2 59.8 45 3 52 364,9 102 Dodoma
# Congo, Dem. Rep. of 562 106.0 48 3 49 905,351 61 Kinshasa
# South Africa 43.6 35.1 34 5 51 471,444 93 Pretoria
# Canada 31.3 36.0 19 13 79 3,849,670 8 Ottawa
# United States 287.4 346.0 21 13 77 3,/17,796 77 Washington, DC
# Mexico 101.7 131.7 33 5 75 756,062 135 Mexico City
# Argentina 36.5 47.2 28 10 74 1,073,514 34 Buenos Aires
# Brazil 173.8 219.0 30 6 69 3,300,154 53 Brasilia
# Colombia 43.8 59.7 33 o 71 439,734 100 Bogota
# Australia & Oceania 32 40 25 10 75 3,306,741 10
# Bangladesh 133.6 177.8 40 3 59 55,598 2,403 Dhaka
# India 1,049.5 1,363.0 36 4 63 1,269,340 827 New Delhi
# Pakistan 143.5 242.1 42 4 63 307,375 467 Islamabad
# Indonesia 217.0 281.9 31 5 68 735,355 295 Jakarta
# Philippines 80.0 115.5 37 4 68 115,83 691 Manila
# Vietnam 19.7 104.1 31 6 68 128,066 622 Hanoi
# China 1,280.7 1,454.7 23 7 71 3,696,100 347 Beijing
# Japan 127.4 121.1 14 18 81 145,869 873 Tokyo
# United Kingdom 60.2 64.8 19 16 78 94,548 637 London
# France 59.5 64.2 19 16 79 212,934 279 Paris
# Germany 82.4 78.1 16 16 78 137,83 598 Berlin
# Russia 143.5 129.1 18 13 65 6,592,819 22 Moscow
# Italy 58.1 57.5 14 19 80 116,32 499 Rome

# %% [markdown]
# ### Extracting Data using Regular Expressions `re`
#
# There are many ways to use Regular Expression to come up with a propoer logic. We want to pick a simple solution to get us to what we want. In our case, we want a DataFrame that looks like this:
#
# <img src='images/dataframe.png' width="500"/>
#
# We don't need any of the data before `Egypt`. We need to capture all the data between `Egypt` to `Rome` according the text structure. Here is an example below:

# %%
guestlist = "This is a list of the top 3 guests that attended the event, I am sendig it based on your request\nJohn Smith\nJames Bond\nJack Back\nLet me know if you need anything else"
print(guestlist)
# Out:
# This is a list of the top 3 guests that attended the event, I am sendig it based on your request
# John Smith
# James Bond
# Jack Back
# Let me know if you need anything else

# %%
regex = re.compile(r'(John|Back)')
matches = regex.finditer(guestlist)

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(97, 101), match='John'>
# <re.Match object; span=(124, 128), match='Back'>

# %%
# I Can store these in a list
regex = re.compile(r'(John|Back)')
matches = regex.finditer(guestlist)
idx = []
for match in matches:
    idx.append([match.start(), match.end()])
idx
# Out:
# [[97, 101], [124, 128]]

# %% [markdown]
# So, this gave me the begining index (97) and ending index (128). What if I use that to slice the big chunk I need to work on?

# %%
smaller = guestlist[idx[0][0]:idx[1][1]]
print(smaller)
# Out:
# John Smith
# James Bond
# Jack Back

# %% [markdown]
# ## Q5 Extract a slice of data that containt the table information using regex (15 pts)

# %%
regex = re.compile(r'(Egypt|Rome)')
matches = regex.finditer(data)
idx = []
for match in matches:
    idx.append([match.start(), match.end()])

# %%
# You should get something like this
print(idx)
# Out:
# [[560, 565], [1830, 1834]]

# %%
# test your results
# my new data slice should be 
dataslice = data[idx[0][0]:idx[1][1]]

# %%
# Example result outcome 
print(dataslice)
# Out:
# Egypt 11.2 96.1 36 4 66 386,66 184 Cairo
# Nigeria 129.9 204.5 44 o 52 356,668 364 Abuja
# Ethiopia 67.7 117.6 44 3 52 426,371 159 Addis Ababa
# Tanzania 37.2 59.8 45 3 52 364,9 102 Dodoma
# Congo, Dem. Rep. of 562 106.0 48 3 49 905,351 61 Kinshasa
# South Africa 43.6 35.1 34 5 51 471,444 93 Pretoria
# Canada 31.3 36.0 19 13 79 3,849,670 8 Ottawa
# United States 287.4 346.0 21 13 77 3,/17,796 77 Washington, DC
# Mexico 101.7 131.7 33 5 75 756,062 135 Mexico City
# Argentina 36.5 47.2 28 10 74 1,073,514 34 Buenos Aires
# Brazil 173.8 219.0 30 6 69 3,300,154 53 Brasilia
# Colombia 43.8 59.7 33 o 71 439,734 100 Bogota
# Australia & Oceania 32 40 25 10 75 3,306,741 10
# Bangladesh 133.6 177.8 40 3 59 55,598 2,403 Dhaka
# India 1,049.5 1,363.0 36 4 63 1,269,340 827 New Delhi
# Pakistan 143.5 242.1 42 4 63 307,375 467 Islamabad
# Indonesia 217.0 281.9 31 5 68 735,355 295 Jakarta
# Philippines 80.0 115.5 37 4 68 115,83 691 Manila
# Vietnam 19.7 104.1 31 6 68 128,066 622 Hanoi
# China 1,280.7 1,454.7 23 7 71 3,696,100 347 Beijing
# Japan 127.4 121.1 14 18 81 145,869 873 Tokyo
# United Kingdom 60.2 64.8 19 16 78 94,548 637 London
# France 59.5 64.2 19 16 79 212,934 279 Paris
# Germany 82.4 78.1 16 16 78 137,83 598 Berlin
# Russia 143.5 129.1 18 13 65 6,592,819 22 Moscow
# Italy 58.1 57.5 14 19 80 116,32 499 Rome

# %% [markdown]
# ## Q6 Now, use Regex again to extract the remaining data and insert into a Data Frame (15 pts)
#
# Here are some suggested steps:
# 1. you can just focus on extracting each line and insert them into a list. The easiest way to think about it, each line luckily ends with `\n` so use Regex to define the beginning and ending of each line
#
# here is an example outcome
#
# ```python
# ['Egypt 11.2 96.1 36 4 66 386,66 184 Cairo\n',
#  'Nigeria 129.9 204.5 44 o 52 356,668 364 Abuja\n',
#  'Ethiopia 67.7 117.6 44 3 52 426,371 159 Addis Ababa\n',
#  'Tanzania 37.2 59.8 45 3 52 364,9 102 Dodoma\n',
#  'Congo, Dem. Rep. of 562 106.0 48 3 49 905,351 61 Kinshasa\n',
#  'South Africa 43.6 35.1 34 5 51 471,444 93 Pretoria\n',
#  'Canada 31.3 36.0 19 13 79 3,849,670 8 Ottawa\n',
#  'United States 287.4 346.0 21 13 77 3,/17,796 77 Washington, DC\n',
#  'Mexico 101.7 131.7 33 5 75 756,062 135 Mexico City\n',
#  'Argentina 36.5 47.2 28 10 74 1,073,514 34 Buenos Aires\n',
#  'Brazil 173.8 219.0 30 6 69 3,300,154 53 Brasilia\n',
#  'Colombia 43.8 59.7 33 o 71 439,734 100 Bogota\n',
#  'Australia & Oceania 32 40 25 10 75 3,306,741 10\n',
#  'Bangladesh 133.6 177.8 40 3 59 55,598 2,403 Dhaka\n',
#  'India 1,049.5 1,363.0 36 4 63 1,269,340 827 New Delhi\n',
#  'Pakistan 143.5 242.1 42 4 63 307,375 467 Islamabad\n',
#  'Indonesia 217.0 281.9 31 5 68 735,355 295 Jakarta\n',
#  'Philippines 80.0 115.5 37 4 68 115,83 691 Manila\n',
#  'Vietnam 19.7 104.1 31 6 68 128,066 622 Hanoi\n',
#  'China 1,280.7 1,454.7 23 7 71 3,696,100 347 Beijing\n',
#  'Japan 127.4 121.1 14 18 81 145,869 873 Tokyo\n',
#  'United Kingdom 60.2 64.8 19 16 78 94,548 637 London\n',
#  'France 59.5 64.2 19 16 79 212,934 279 Paris\n',
#  'Germany 82.4 78.1 16 16 78 137,83 598 Berlin\n',
#  'Russia 143.5 129.1 18 13 65 6,592,819 22 Moscow\n',
#  'Italy 58.1 57.5 14 19 80 116,32 499 Rome']
#  ```
#
# You can then loop through the array to further extract and transform your data into a nice dictionary that you can later on convert ito a pandas DataFrame:
#
# ```python
# [{'Country': 'Egypt ',
#   'Population (2002)': '11.2',
#   'Project Population (2025)': '96.1'},
#  {'Country': 'Nigeria ',
#   'Population (2002)': '129.9',
#   'Project Population (2025)': '204.5'},
#  {'Country': 'Ethiopia ',
#   'Population (2002)': '67.7',
#   'Project Population (2025)': '117.6'},
#  {'Country': 'Tanzania ',
#   'Population (2002)': '37.2',
#   'Project Population (2025)': '59.8'},
#  {'Country': 'Congo, Dem. Rep. of ',
#   'Population (2002)': '562',
#   'Project Population (2025)': '106.0'},
#  {'Country': 'South Africa ',
#   'Population (2002)': '43.6',
#   'Project Population (2025)': '35.1'},
#  {'Country': 'Canada ',
#   'Population (2002)': '31.3',
#   'Project Population (2025)': '36.0'},
#  {'Country': 'United States ',
#   'Population (2002)': '287.4',
#   'Project Population (2025)': '346.0'},
#  {'Country': 'Mexico ',
#   'Population (2002)': '101.7',
#   'Project Population (2025)': '131.7'},
#  {'Country': 'Argentina ',
#   'Population (2002)': '36.5',
#   'Project Population (2025)': '47.2'},
#  {'Country': 'Brazil ',
#   'Population (2002)': '173.8',
#   'Project Population (2025)': '219.0'},
#  {'Country': 'Colombia ',
#   'Population (2002)': '43.8',
#   'Project Population (2025)': '59.7'},
#  {'Country': 'Australia & Oceania ',
#   'Population (2002)': '32',
#   'Project Population (2025)': '40'},
#  {'Country': 'Bangladesh ',
#   'Population (2002)': '133.6',
#   'Project Population (2025)': '177.8'},
#  {'Country': 'India ',
#   'Population (2002)': '1,049.5',
#   'Project Population (2025)': '1,363.0'},
#  {'Country': 'Pakistan ',
#   'Population (2002)': '143.5',
#   'Project Population (2025)': '242.1'},
#  {'Country': 'Indonesia ',
#   'Population (2002)': '217.0',
#   'Project Population (2025)': '281.9'},
#  {'Country': 'Philippines ',
#   'Population (2002)': '80.0',
#   'Project Population (2025)': '115.5'},
#  {'Country': 'Vietnam ',
#   'Population (2002)': '19.7',
#   'Project Population (2025)': '104.1'},
#  {'Country': 'China ',
#   'Population (2002)': '1,280.7',
#   'Project Population (2025)': '1,454.7'},
#  {'Country': 'Japan ',
#   'Population (2002)': '127.4',
#   'Project Population (2025)': '121.1'},
#  {'Country': 'United Kingdom ',
#   'Population (2002)': '60.2',
#   'Project Population (2025)': '64.8'},
#  {'Country': 'France ',
#   'Population (2002)': '59.5',
#   'Project Population (2025)': '64.2'},
#  {'Country': 'Germany ',
#   'Population (2002)': '82.4',
#   'Project Population (2025)': '78.1'},
#  {'Country': 'Russia ',
#   'Population (2002)': '143.5',
#   'Project Population (2025)': '129.1'},
#  {'Country': 'Italy ',
#   'Population (2002)': '58.1',
#   'Project Population (2025)': '57.5'}]
#  ```
#
# then you can use `pd.DataFrame(dictionary)`

# %%
# There are helper functions that you can use if you want to test if 
# specific string is number or float before casting to avoid errors

def isnumeric(x):
    try:
        num = float(x)
    except ValueError:
        return False
    return True

def isdigit(x):
    x = x.replace(',', '')
    try:
        num = int(x)
    except ValueError:
        return False
    return True

# %%
#check dataslice content beginning and ending point
regex = re.compile(r'(Egypt|Rome)')
matches = regex.finditer(dataslice)
idx = []
for match in matches:
    idx.append([match.start(), match.end()])
print(idx)
# Out:
# [[0, 5], [1270, 1274]]

# %%
# Method 1
regex = re.compile(r'\n')
matche2s = regex.finditer(dataslice)
poplist=[]
i=0
for match2 in matche2s:
    mend=match2.end()
    poplist.append(dataslice[i:mend])
    i=+mend
#append the last line without \n
poplist.append(dataslice[mend:1274])
poplist
# Out:
# ['Egypt 11.2 96.1 36 4 66 386,66 184 Cairo\n',
#  'Nigeria 129.9 204.5 44 o 52 356,668 364 Abuja\n',
#  'Ethiopia 67.7 117.6 44 3 52 426,371 159 Addis Ababa\n',
#  'Tanzania 37.2 59.8 45 3 52 364,9 102 Dodoma\n',
#  'Congo, Dem. Rep. of 562 106.0 48 3 49 905,351 61 Kinshasa\n',
#  'South Africa 43.6 35.1 34 5 51 471,444 93 Pretoria\n',
#  'Canada 31.3 36.0 19 13 79 3,849,670 8 Ottawa\n',
#  'United States 287.4 346.0 21 13 77 3,/17,796 77 Washington, DC\n',
#  'Mexico 101.7 131.7 33 5 75 756,062 135 Mexico City\n',
#  'Argentina 36.5 47.2 28 10 74 1,073,514 34 Buenos Aires\n',
#  'Brazil 173.8 219.0 30 6 69 3,300,154 53 Brasilia\n',
#  'Colombia 43.8 59.7 33 o 71 439,734 100 Bogota\n',
#  'Australia & Oceania 32 40 25 10 75 3,306,741 10\n',
#  'Bangladesh 133.6 177.8 40 3 59 55,598 2,403 Dhaka\n',
#  'India 1,049.5 1,363.0 36 4 63 1,269,340 827 New Delhi\n',
#  'Pakistan 143.5 242.1 42 4 63 307,375 467 Islamabad\n',
#  'Indonesia 217.0 281.9 31 5 68 735,355 295 Jakarta\n',
#  'Philippines 80.0 115.5 37 4 68 115,83 691 Manila\n',
#  'Vietnam 19.7 104.1 31 6 68 128,066 622 Hanoi\n',
#  'China 1,280.7 1,454.7 23 7 71 3,696,100 347 Beijing\n',
#  'Japan 127.4 121.1 14 18 81 145,869 873 Tokyo\n',
#  'United Kingdom 60.2 64.8 19 16 78 94,548 637 London\n',
#  'France 59.5 64.2 19 16 79 212,934 279 Paris\n',
#  'Germany 82.4 78.1 16 16 78 137,83 598 Berlin\n',
#  'Russia 143.5 129.1 18 13 65 6,592,819 22 Moscow\n',
#  'Italy 58.1 57.5 14 19 80 116,32 499 Rome']

# %%
#test
a=poplist[14]
regex = re.compile(r'\D+\s')
matches = regex.finditer(a)
idx3=[]
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 6), match='India '>
# <re.Match object; span=(43, 54), match=' New Delhi\n'>

# %%
arrayList=[]
for e in poplist:
#use regular expression get the country name
    regex = re.compile(r'\D+')
    matches = regex.finditer(e)
    idx3=[]
    for match in matches:
        popdict={}
        idx3.append([match.start(), match.end()])
#git extract country name and git rid of the white space after country name
        popdict["country"] = e[idx3[0][0]:(idx3[0][1]-1)]
#     arrayList.append(popdict)
#Extract population
    regex = re.compile(r'\d+[,.]?\d+[,.]?\d+|\d+')
    matches = regex.finditer(e)
    idx3=[]
    for match in matches:
        idx3.append([match.start(), match.end()])
        popdict["Population (2002)"] = e[idx3[0][0]:idx3[0][1]]
#Extract projection population
    regex = re.compile(r'\d+[,.]?\d+[,.]?\d+|\d+')
    matches = regex.finditer(e)
    idx3=[]
    for match in matches:
        idx3.append([match.start(), match.end()])
    popdict["Projected Population (2025)"] = e[idx3[1][0]:idx3[1][1]]
    arrayList.append(popdict)
arrayList
# Out:
# [{'country': 'Egypt',
#   'Population (2002)': '11.2',
#   'Projected Population (2025)': '96.1'},
#  {'country': 'Nigeria',
#   'Population (2002)': '129.9',
#   'Projected Population (2025)': '204.5'},
#  {'country': 'Ethiopia',
#   'Population (2002)': '67.7',
#   'Projected Population (2025)': '117.6'},
#  {'country': 'Tanzania',
#   'Population (2002)': '37.2',
#   'Projected Population (2025)': '59.8'},
#  {'country': 'Congo, Dem. Rep. of',
#   'Population (2002)': '562',
#   'Projected Population (2025)': '106.0'},
#  {'country': 'South Africa',
#   'Population (2002)': '43.6',
#   'Projected Population (2025)': '35.1'},
#  {'country': 'Canada',
#   'Population (2002)': '31.3',
#   'Projected Population (2025)': '36.0'},
#  {'country': 'United States',
#   'Population (2002)': '287.4',
#   'Projected Population (2025)': '346.0'},
#  {'country': 'Mexico',
#   'Population (2002)': '101.7',
#   'Projected Population (2025)': '131.7'},
#  {'country': 'Argentina',
#   'Population (2002)': '36.5',
#   'Projected Population (2025)': '47.2'},
#  {'country': 'Brazil',
#   'Population (2002)': '173.8',
#   'Projected Population (2025)': '219.0'},
#  {'country': 'Colombia',
#   'Population (2002)': '43.8',
#   'Projected Population (2025)': '59.7'},
#  {'country': 'Australia & Oceania',
#   'Population (2002)': '32',
#   'Projected Population (2025)': '40'},
#  {'country': 'Bangladesh',
#   'Population (2002)': '133.6',
#   'Projected Population (2025)': '177.8'},
#  {'country': 'India',
#   'Population (2002)': '1,049.5',
#   'Projected Population (2025)': '1,363.0'},
#  {'country': 'Pakistan',
#   'Population (2002)': '143.5',
#   'Projected Population (2025)': '242.1'},
#  {'country': 'Indonesia',
#   'Population (2002)': '217.0',
#   'Projected Population (2025)': '281.9'},
#  {'country': 'Philippines',
#   'Population (2002)': '80.0',
#   'Projected Population (2025)': '115.5'},
#  {'country': 'Vietnam',
#   'Population (2002)': '19.7',
#   'Projected Population (2025)': '104.1'},
#  {'country': 'China',
#   'Population (2002)': '1,280.7',
#   'Projected Population (2025)': '1,454.7'},
#  {'country': 'Japan',
#   'Population (2002)': '127.4',
#   'Projected Population (2025)': '121.1'},
#  {'country': 'United Kingdom',
#   'Population (2002)': '60.2',
#   'Projected Population (2025)': '64.8'},
#  {'country': 'France',
#   'Population (2002)': '59.5',
#   'Projected Population (2025)': '64.2'},
#  {'country': 'Germany',
#   'Population (2002)': '82.4',
#   'Projected Population (2025)': '78.1'},
#  {'country': 'Russia',
#   'Population (2002)': '143.5',
#   'Projected Population (2025)': '129.1'},
#  {'country': 'Italy',
#   'Population (2002)': '58.1',
#   'Projected Population (2025)': '57.5'}]

# %%
pop_df=pd.DataFrame(arrayList)
pop_df
# Out:
#                 country Population (2002) Projected Population (2025)
# 0                 Egypt              11.2                        96.1
# 1               Nigeria             129.9                       204.5
# 2              Ethiopia              67.7                       117.6
# 3              Tanzania              37.2                        59.8
# 4   Congo, Dem. Rep. of               562                       106.0
# 5          South Africa              43.6                        35.1
# 6                Canada              31.3                        36.0
# 7         United States             287.4                       346.0
# 8                Mexico             101.7                       131.7
# 9             Argentina              36.5                        47.2
# 10               Brazil             173.8                       219.0
# 11             Colombia              43.8                        59.7
# 12  Australia & Oceania                32                          40
# 13           Bangladesh             133.6                       177.8
# 14                India           1,049.5                     1,363.0
# 15             Pakistan             143.5                       242.1
# 16            Indonesia             217.0                       281.9
# 17          Philippines              80.0                       115.5
# 18              Vietnam              19.7                       104.1
# 19                China           1,280.7                     1,454.7
# 20                Japan             127.4                       121.1
# 21       United Kingdom              60.2                        64.8
# 22               France              59.5                        64.2
# 23              Germany              82.4                        78.1
# 24               Russia             143.5                       129.1
# 25                Italy              58.1                        57.5

# %%
pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
# country                        26 non-null object
# Population (2002)              26 non-null object
# Projected Population (2025)    26 non-null object
# dtypes: object(3)
# memory usage: 752.0+ bytes

# %% [markdown]
# ## Q6: Pandas data cleanup and visualization (15 pts)
#
# 1. `Population 2002` and `Projected Population 2025` should be converted to floats.
# 2. Create two pandas visualiztions like below (I have four, but create any two)

# %%
pop_df['Population (2002)'] = pop_df['Population (2002)'].str.replace(",","")
pop_df['Population (2002)'] = pop_df['Population (2002)'].astype('float')
pop_df['Projected Population (2025)'] = pop_df['Projected Population (2025)'].str.replace(",","")
pop_df['Projected Population (2025)'] = pop_df['Projected Population (2025)'].astype('float')

# %%
import matplotlib.pyplot as plt

# %%
pop_df.plot(kind='bar',x='country',y='Population (2002)')

# %%
pop_df.plot(kind='bar',x='country',y='Projected Population (2025)')

# %%
pop_df2=pop_df.copy()
pop_df2=pop_df2.set_index('country')
china_india_df=pop_df2.loc[['India','China']]
china_india_df.plot(kind='bar')

# %%
cuic_df=pop_df2.loc[['Canada','United States','India','China']]
cuic_df.plot(kind='bar')

# %% [markdown]
# Interesting observation: It seems both China and India have the largest estimate for population in terms of future projection. But let's investigate this further. We have another dataset from World Bank regarding China that we will load and examine further to better understand our initial analysis.

# %%
china = pd.read_csv('Data/China/API_CHN_DS2_en_csv_v2_615059.csv', 
                    skip_blank_lines=True, 
                    skiprows=4)

# %%
china.head()
# Out:
#   Country Name Country Code  \
# 0        China          CHN
# 1        China          CHN
# 2        China          CHN
# 3        China          CHN
# 4        China          CHN
#
#                                       Indicator Name     Indicator Code  \
# 0  Population ages 40-44, female (% of female pop...  SP.POP.4044.FE.5Y
# 1  Population ages 35-39, male (% of male populat...  SP.POP.3539.MA.5Y
# 2  Population ages 35-39, female (% of female pop...  SP.POP.3539.FE.5Y
# 3  Population ages 30-34, male (% of male populat...  SP.POP.3034.MA.5Y
# 4  Population ages 30-34, female (% of female pop...  SP.POP.3034.FE.5Y
#
#        1960      1961      1962      1963      1964      1965  ...      2011  \
# 0  5.551835  5.478411  5.347071  5.191094  5.052465  4.948230  ...  9.407978
# 1  5.919494  5.905192  5.898749  5.903042  5.919873  5.943034  ...  8.500235
# 2  5.738536  5.677073  5.598823  5.524227  5.477104  5.462105  ...  8.548305
# 3  6.780982  6.841904  6.852674  6.830259  6.799692  6.767670  ...  6.912692
# 4  6.283533  6.328102  6.356205  6.367457  6.360458  6.328613  ...  6.935184
#
#        2012      2013      2014      2015      2016      2017      2018  2019  \
# 0  9.347677  9.189468  8.947521  8.637590  8.264010  7.826342  7.375617   NaN
# 1  8.052052  7.584342  7.176343  6.879643  6.685844  6.583946  6.587374   NaN
# 2  8.089537  7.617409  7.206976  6.906939  6.709267  6.604155  6.603480   NaN
# 3  6.800519  6.797166  6.916692  7.157209  7.520793  8.025598  8.549579   NaN
# 4  6.821417  6.814965  6.928836  7.160112  7.510158  7.998682  8.501577   NaN
#
#    Unnamed: 64
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 65 columns]

# %%
china.tail()
# Out:
#      Country Name Country Code  \
# 1424        China          CHN
# 1425        China          CHN
# 1426        China          CHN
# 1427        China          CHN
# 1428        China          CHN
#
#                                          Indicator Name  Indicator Code  1960  \
# 1424  PNG, commercial banks and other creditors (NFL...  DT.NFL.PNGC.CD   NaN
# 1425                      PNG, bonds (NFL, current US$)  DT.NFL.PNGB.CD   NaN
# 1426  Commercial banks and other lending (PPG + PNG)...  DT.NFL.PCBO.CD   NaN
# 1427           PPG, commercial banks (NFL, current US$)  DT.NFL.PCBK.CD   NaN
# 1428                      PPG, bonds (NFL, current US$)  DT.NFL.PBND.CD   NaN
#
#       1961  1962  1963  1964  1965  ...          2011          2012  \
# 1424   NaN   NaN   NaN   NaN   NaN  ...  1.536400e+10  7.360843e+09
# 1425   NaN   NaN   NaN   NaN   NaN  ...  1.310570e+10  1.939326e+10
# 1426   NaN   NaN   NaN   NaN   NaN  ...  2.841636e+10  1.594303e+10
# 1427   NaN   NaN   NaN   NaN   NaN  ...  1.703986e+10  9.306825e+09
# 1428   NaN   NaN   NaN   NaN   NaN  ...  1.192363e+10  1.623800e+10
#
#               2013          2014          2015          2016          2017  \
# 1424  4.624714e+09  3.513015e+10  3.299460e+10  6.781624e+09 -3.347714e+09
# 1425  2.207590e+10  3.498638e+10 -2.766385e+09  1.974929e+10  5.010177e+10
# 1426  1.889475e+10  4.505679e+10  1.977279e+10  1.951698e+10  3.824159e+09
# 1427  1.045289e+10  1.033500e+10 -1.145931e+10  1.350918e+10  7.369273e+09
# 1428  6.405000e+09  1.889375e+10  1.154201e+10  2.523987e+09  3.198586e+10
#
#               2018  2019  Unnamed: 64
# 1424 -5.855178e+09   NaN          NaN
# 1425  3.169336e+10   NaN          NaN
# 1426  2.005511e+09   NaN          NaN
# 1427  7.800477e+09   NaN          NaN
# 1428  3.692071e+10   NaN          NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# There are so many indicators. We just want to focus on two groups: Ages 15-64 we can refer to them as **Adults**, and ages 0-14 we can refer to them as **Children**

# %%
indicators = ['Population ages 15-64, total', 'Population ages 0-14, total']
chinapop = china[china['Indicator Name'].isin(indicators)].iloc[:,:-2]

# %%
chinapop
# Out:
#    Country Name Country Code                Indicator Name  Indicator Code  \
# 10        China          CHN  Population ages 15-64, total  SP.POP.1564.TO
# 22        China          CHN   Population ages 0-14, total  SP.POP.0014.TO
#
#            1960         1961         1962         1963         1964  \
# 10  376823164.0  372520588.0  373118860.0  379332695.0  386528523.0
# 22  265641893.0  263302831.0  268188604.0  278443818.0  287297670.0
#
#            1965  ...         2009         2010         2011         2012  \
# 10  396196818.0  ...  974558542.0  980077454.0  984319837.0  988398458.0
# 22  294501997.0  ...  251102769.0  249615182.0  248796397.0  248118129.0
#
#            2013         2014         2015         2016         2017  \
# 10  991985917.0  994542472.0  995702268.0  995434082.0  994288090.0
# 22  247587326.0  247401658.0  247557811.0  248085474.0  248682677.0
#
#            2018
# 10  991653198.0
# 22  248978380.0
#
# [2 rows x 63 columns]

# %%
# let's pick one slice and examine Adults
adults = chinapop.iloc[:1, 4:]
adults
# Out:
#            1960         1961         1962         1963         1964  \
# 10  376823164.0  372520588.0  373118860.0  379332695.0  386528523.0
#
#            1965         1966         1967         1968         1969  ...  \
# 10  396196818.0  405508463.0  416669512.0  429726357.0  443537016.0  ...
#
#            2009         2010         2011         2012         2013  \
# 10  974558542.0  980077454.0  984319837.0  988398458.0  991985917.0
#
#            2014         2015         2016         2017         2018
# 10  994542472.0  995702268.0  995434082.0  994288090.0  991653198.0
#
# [1 rows x 59 columns]

# %% [markdown]
# ## Q7: Convert the `adults` to the format below (5 pts)
# Hint: [pandas melt](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.melt.html)

# %%
## YOUR CODE HERE
adults=adults.T.reset_index()
adults=adults.rename(columns = {'index':'variable',10:'value'})
# adults= adults_new2
adults
# Out:
#    variable        value
# 0      1960  376823164.0
# 1      1961  372520588.0
# 2      1962  373118860.0
# 3      1963  379332695.0
# 4      1964  386528523.0
# 5      1965  396196818.0
# 6      1966  405508463.0
# 7      1967  416669512.0
# 8      1968  429726357.0
# 9      1969  443537016.0
# 10     1970  456985978.0
# 11     1971  468991340.0
# 12     1972  480278464.0
# 13     1973  491368033.0
# 14     1974  502557702.0
# 15     1975  513861540.0
# 16     1976  526008005.0
# 17     1977  538475659.0
# 18     1978  552194383.0
# 19     1979  567184356.0
# 20     1980  582756908.0
# 21     1981  600164693.0
# 22     1982  618735725.0
# 23     1983  637261940.0
# 24     1984  654846220.0
# 25     1985  672180280.0
# 26     1986  687782548.0
# 27     1987  703389691.0
# 28     1988  718310123.0
# 29     1989  732531057.0
# 30     1990  746726066.0
# 31     1991  756677632.0
# 32     1992  768952440.0
# 33     1993  782325624.0
# 34     1994  794860325.0
# 35     1995  805367614.0
# 36     1996  820493214.0
# 37     1997  831124788.0
# 38     1998  839669246.0
# 39     1999  849907147.0
# 40     2000  863641938.0
# 41     2001  875614116.0
# 42     2002  891647554.0
# 43     2003  909846945.0
# 44     2004  926808358.0
# 45     2005  940817540.0
# 46     2006  952765169.0
# 47     2007  961863202.0
# 48     2008  968715052.0
# 49     2009  974558542.0
# 50     2010  980077454.0
# 51     2011  984319837.0
# 52     2012  988398458.0
# 53     2013  991985917.0
# 54     2014  994542472.0
# 55     2015  995702268.0
# 56     2016  995434082.0
# 57     2017  994288090.0
# 58     2018  991653198.0

# %% [markdown]
# ## Q7 Rename the column `variable` to `year` (5 pts)

# %%
# rename the columns

adults=adults.rename(columns = {'variable':'year'})
adults
# Out:
#     year        value
# 0   1960  376823164.0
# 1   1961  372520588.0
# 2   1962  373118860.0
# 3   1963  379332695.0
# 4   1964  386528523.0
# 5   1965  396196818.0
# 6   1966  405508463.0
# 7   1967  416669512.0
# 8   1968  429726357.0
# 9   1969  443537016.0
# 10  1970  456985978.0
# 11  1971  468991340.0
# 12  1972  480278464.0
# 13  1973  491368033.0
# 14  1974  502557702.0
# 15  1975  513861540.0
# 16  1976  526008005.0
# 17  1977  538475659.0
# 18  1978  552194383.0
# 19  1979  567184356.0
# 20  1980  582756908.0
# 21  1981  600164693.0
# 22  1982  618735725.0
# 23  1983  637261940.0
# 24  1984  654846220.0
# 25  1985  672180280.0
# 26  1986  687782548.0
# 27  1987  703389691.0
# 28  1988  718310123.0
# 29  1989  732531057.0
# 30  1990  746726066.0
# 31  1991  756677632.0
# 32  1992  768952440.0
# 33  1993  782325624.0
# 34  1994  794860325.0
# 35  1995  805367614.0
# 36  1996  820493214.0
# 37  1997  831124788.0
# 38  1998  839669246.0
# 39  1999  849907147.0
# 40  2000  863641938.0
# 41  2001  875614116.0
# 42  2002  891647554.0
# 43  2003  909846945.0
# 44  2004  926808358.0
# 45  2005  940817540.0
# 46  2006  952765169.0
# 47  2007  961863202.0
# 48  2008  968715052.0
# 49  2009  974558542.0
# 50  2010  980077454.0
# 51  2011  984319837.0
# 52  2012  988398458.0
# 53  2013  991985917.0
# 54  2014  994542472.0
# 55  2015  995702268.0
# 56  2016  995434082.0
# 57  2017  994288090.0
# 58  2018  991653198.0

# %% [markdown]
# We will set `year` as the DataFrame Index to get a Time Series plot

# %%
adults = adults.set_index('year')
plt.figure(figsize=(12,5))
plt.plot(adults)

# %% [markdown]
# The graph has many issues. In order for Pandas to recognize this as a Time Series, the index which is currently as `object` needs to be converted to a `datetime`

# %%
adults.index
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018'],
#       dtype='object', name='year')

# %% [markdown]
# ## Q8: Convert the index to datetime (5 pts)

# %%
#YOUR CODE HERE
adults.index = pd.to_datetime(adults.index)

# %%
adults.index
# Out:
# DatetimeIndex(['1960-01-01', '1961-01-01', '1962-01-01', '1963-01-01',
#                '1964-01-01', '1965-01-01', '1966-01-01', '1967-01-01',
#                '1968-01-01', '1969-01-01', '1970-01-01', '1971-01-01',
#                '1972-01-01', '1973-01-01', '1974-01-01', '1975-01-01',
#                '1976-01-01', '1977-01-01', '1978-01-01', '1979-01-01',
#                '1980-01-01', '1981-01-01', '1982-01-01', '1983-01-01',
#                '1984-01-01', '1985-01-01', '1986-01-01', '1987-01-01',
#                '1988-01-01', '1989-01-01', '1990-01-01', '1991-01-01',
#                '1992-01-01', '1993-01-01', '1994-01-01', '1995-01-01',
#                '1996-01-01', '1997-01-01', '1998-01-01', '1999-01-01',
#                '2000-01-01', '2001-01-01', '2002-01-01', '2003-01-01',
#                '2004-01-01', '2005-01-01', '2006-01-01', '2007-01-01',
#                '2008-01-01', '2009-01-01', '2010-01-01', '2011-01-01',
#                '2012-01-01', '2013-01-01', '2014-01-01', '2015-01-01',
#                '2016-01-01', '2017-01-01', '2018-01-01'],
#               dtype='datetime64[ns]', name='year', freq=None)

# %%
# Let's try the plot again
plt.figure(figsize=(12,5))
plt.plot(adults)

# %% [markdown]
# ## Q9: Follow the sames steps but this time for the children (15 pts)

# %%
children = chinapop.iloc[1:2, 4:]
# YOUR CODE HERE
children=children.T.reset_index()
children=children.rename(columns = {'index':'variable',22:'value'})
# adults= adults_new2
children
# Out:
#    variable        value
# 0      1960  265641893.0
# 1      1961  263302831.0
# 2      1962  268188604.0
# 3      1963  278443818.0
# 4      1964  287297670.0
# 5      1965  294501997.0
# 6      1966  304216738.0
# 7      1967  310976161.0
# 8      1968  316601067.0
# 9      1969  323033758.0
# 10     1970  330658357.0
# 11     1971  340015460.0
# 12     1972  348297760.0
# 13     1973  355789052.0
# 14     1974  361683794.0
# 15     1975  365103747.0
# 16     1976  365617362.0
# 17     1977  364299712.0
# 18     1978  361610403.0
# 19     1979  357715831.0
# 20     1980  352611901.0
# 21     1981  345762315.0
# 22     1982  339804660.0
# 23     1983  333897749.0
# 24     1984  327940857.0
# 25     1985  323050142.0
# 26     1986  321493844.0
# 27     1987  321547481.0
# 28     1988  322714350.0
# 29     1989  323955099.0
# 30     1990  324546177.0
# 31     1991  328581656.0
# 32     1992  328596758.0
# 33     1993  326580984.0
# 34     1994  325280651.0
# 35     1995  325698399.0
# 36     1996  320435561.0
# 37     1997  319849182.0
# 38     1998  320906193.0
# 39     1999  319203340.0
# 40     2000  312993544.0
# 41     2001  307972185.0
# 42     2002  298071840.0
# 43     2003  285390312.0
# 44     2004  273788404.0
# 45     2005  265351992.0
# 46     2006  258543763.0
# 47     2007  254375415.0
# 48     2008  252408571.0
# 49     2009  251102769.0
# 50     2010  249615182.0
# 51     2011  248796397.0
# 52     2012  248118129.0
# 53     2013  247587326.0
# 54     2014  247401658.0
# 55     2015  247557811.0
# 56     2016  248085474.0
# 57     2017  248682677.0
# 58     2018  248978380.0

# %%
children=children.rename(columns = {'variable':'year'})
plt.figure(figsize=(12,5))
plt.plot(children)

# %%
children.index = pd.to_datetime(children.index)
plt.figure(figsize=(12,5))
plt.plot(children)

# %% [markdown]
# ## Q10: I was able to combine into one chart. When you look at this, do you see any alarming trend? What are your thoughts? (5 pts)

# %% [markdown]
# <img src="images/analysis.png"/>

# %%
df = adults.merge(children, left_index=True, right_index=True)
df.columns = ["values_adults","values_children"]
df.head()
# Out:
#             values_adults  values_children
# year
# 1960-01-01    376823164.0      265641893.0
# 1961-01-01    372520588.0      263302831.0
# 1962-01-01    373118860.0      268188604.0
# 1963-01-01    379332695.0      278443818.0
# 1964-01-01    386528523.0      287297670.0

# %%
plt.figure(figsize=(12,5))
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x1e6512da908>,
#  <matplotlib.lines.Line2D at 0x1e651304408>]

# %%
plt.figure(figsize=(12,5))
plt.plot(adults)
plt.plot(children)
plt.show()

# %% [markdown]
# ### Analysis

# %% [markdown]
# ##### 1. The number of new born babies in China starts decrease after 1976, compare to the adults number in China from 1960 to 2020. The reason is China starts the one kid policy from 1976 and it became an official policy in China at 1982.
# ##### 2 . The population of new born babies in China becomes dropping slowly after year 2015, since China cancel the one kid policy after 2015
# ##### 3. China is facing an Aging Problem in the future 20 years, it may casue a serious economic problem.
